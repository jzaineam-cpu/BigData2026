# %% [markdown]
# <a href="https://colab.research.google.com/github/jazaineam1/BigData2026/blob/main/sesion1_introducci_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Introducción a Big Data e ingesta de datos en python***
#
# ## ***Universidad Central***
# >## **Facultad de Ingeniería y Ciencias Básicas.**
# >## ***Maestría en analítica de datos***
# ![Imágen1](https://universidad.ucentral.edu.co/tulengua/wp-content/themes/tulengua/images/logo-ucentral.png)
#
#
# >## ***Big Data.***
# >## ***Docente: Antonino Zainea Maya.***

# %% [markdown]
# ## Parte 1
#
# ### Introducción
#
# En el mundo digital actual, es importante entender la cantidad de datos que las plataformas en línea recopilan sobre nosotros y cómo esta información se utiliza para personalizar servicios y anuncios. A continuación, exploramos algunas de las principales empresas y la información que pueden recopilar:
#
# 1. Google y su Recopilación de Datos:
#
# Al utilizar servicios de Google como Gmail, es esencial leer detenidamente la política de privacidad para comprender qué datos estamos autorizando compartir. Google rastrea nuestras búsquedas, ubicaciones y viajes, y utiliza estos datos para dirigir anuncios específicos hacia nosotros.
#
# 2. Facebook y su Conocimiento Detallado:
#
# Facebook sabe detalles sobre nuestras relaciones, intereses y actividades, lo que puede influir en los anuncios que vemos. Incluso puede predecir el deterioro de relaciones basándose en patrones en la plataforma. La capacidad de la plataforma para inferir rasgos emocionales a través de las interacciones también es notable.
#
# 3. Twitter y las Implicaciones Personales:
#
# Twitter también tiene la capacidad de inferir nuestra estabilidad emocional basándose en nuestras interacciones y publicaciones. Algunas empresas incluso utilizan análisis de redes sociales durante los procesos de selección.
#
# 4. Apple y la Continuidad de la Conexión:
#
# Los iPhones están diseñados de manera que la batería no se pueda extraer, lo que puede llevar a que el dispositivo siempre esté conectado. Esto ha llevado a especulaciones sobre si los datos se transmiten incluso cuando el teléfono está apagado o sin batería.
#
# 5. YouTube y Amazon: Personalización y Recomendaciones:
#
# Plataformas como YouTube y Amazon recopilan información sobre los videos que vemos y las compras que realizamos, respectivamente. Esta información se utiliza para recomendaciones personalizadas, lo que contribuye a la experiencia del usuario.

# %% [markdown]
# <span class="hljs-tag"><img src="https://st3.idealista.com/news/archivos/styles/fullwidth_xl/public/2025-04/images/daily_internet_activity-site.jpg?VersionId=hchx_9ZCUNAS20RtwuZs904ZwF66wuZJ&itok=8AS0dwkK" width="580">

# %% [markdown]
# La actual era, a menudo denominada "era de la información" o "era digital", se caracteriza por la abundancia de datos y la rápida evolución de la tecnología de la información. En esta era, la industria ha experimentado una transformación significativa en la forma en que opera y toma decisiones debido al acceso y la disponibilidad de grandes volúmenes de información. Aquí hay algunas razones clave por las cuales el manejo de grandes volúmenes de información es crucial en la industria en esta era:
#
# 1. **Toma de decisiones informadas:** 🧐📊 Las organizaciones pueden tomar decisiones más informadas y estratégicas al analizar grandes conjuntos de datos. Esto les permite comprender mejor el mercado, los patrones de consumo, las preferencias del cliente y las tendencias emergentes. La toma de decisiones basada en datos es esencial para mantenerse competitivo en un entorno empresarial en constante cambio.
#
# 2. **Personalización y segmentación:** 🎯👥 Con acceso a grandes cantidades de datos, las empresas pueden personalizar sus productos y servicios de acuerdo con las necesidades y preferencias individuales de los clientes. Esto les permite dirigirse a segmentos específicos de la población de manera más efectiva, mejorando así la experiencia del cliente y aumentando la lealtad.
#
# 3. **Optimización de procesos:** ⚙️📈 El análisis de grandes volúmenes de datos puede revelar ineficiencias y áreas de mejora en los procesos empresariales. Al identificar estos puntos débiles, las organizaciones pueden optimizar sus operaciones, reducir costos y mejorar la eficiencia en general.
#
# 4. **Innovación:** 💡🚀 La exploración de grandes cantidades de datos puede conducir a descubrimientos y patrones inesperados que pueden generar nuevas ideas y oportunidades de innovación. Al identificar correlaciones y relaciones que no eran evidentes anteriormente, las empresas pueden desarrollar productos y servicios innovadores.
#
# 5. **Predicción y prevención:** 🔮🕵️‍♂️ Mediante el análisis de datos históricos y en tiempo real, las empresas pueden predecir tendencias futuras y riesgos potenciales. Esto es especialmente valioso en sectores como la salud, la seguridad cibernética y la gestión de la cadena de suministro, donde la anticipación de problemas puede marcar la diferencia.
#
# 6. **Mejora de la experiencia del cliente:** 🛍️👤 Las empresas pueden utilizar datos para comprender mejor el viaje del cliente y mejorar su experiencia en todas las etapas. Esto incluye desde la adquisición inicial hasta la retención y el servicio postventa, lo que conduce a relaciones más sólidas con los clientes.
#
# 7. **Investigación y desarrollo:** 🔬💼 En industrias como la farmacéutica y la tecnología, el análisis de grandes conjuntos de datos puede acelerar la investigación y el desarrollo al identificar patrones y relaciones en la información recopilada.
#
# 8. **Competitividad:** 🏆📈 Aquellas organizaciones que pueden aprovechar eficazmente grandes volúmenes de datos tienen una ventaja competitiva en el mercado. La capacidad de adaptarse y responder a los cambios en función de la información en tiempo real puede marcar una gran diferencia en la capacidad de una empresa para mantenerse relevante y competitiva.

# %% [markdown]
# ![](https://pbs.twimg.com/media/EFz4Xl2XUAA4G8z?format=jpg&name=900x900)

# %% [markdown]
# El análisis de conjuntos de datos de Big Data es un esfuerzo interdisciplinario que combina matemáticas, estadísticas, ciencias de la computación y experiencia en la materia. Esta mezcla de conjuntos de habilidades y perspectivas ha generado cierta confusión sobre lo que comprende el campo del Big Data y su análisis, ya que la respuesta que se recibe dependerá de la perspectiva de quien responda a la pregunta. Los límites de lo que constituye un problema de Big Data también están cambiando debido al paisaje en constante cambio y avance de la tecnología de software y hardware. Esto se debe al hecho de que la definición de Big Data tiene en cuenta el impacto de las características de los datos en el diseño del entorno de solución en sí mismo. Hace treinta años, un gigabyte de datos podía representar un problema de Big Data y requerir recursos informáticos especiales. Ahora, los gigabytes de datos son comunes y se pueden transmitir, procesar y almacenar fácilmente en dispositivos orientados al consumidor.
#
# Los datos dentro de los entornos de Big Data generalmente se acumulan al ser recopilados dentro de la empresa a través de aplicaciones, sensores y fuentes externas. Los datos procesados por una solución de Big Data pueden ser utilizados directamente por las aplicaciones empresariales o pueden ser alimentados en un almacén de datos para enriquecer los datos existentes allí. Los resultados obtenidos a través del procesamiento de Big Data pueden llevar a una amplia gama de conocimientos y beneficios, como:
#
#
#
# - Optimización operativa 🔄📊
# - Inteligencia accionable 🧠💡
# - Identificación de nuevos mercados 🌍🔍
# - Predicciones precisas 🎯🔮
# - Detección de fallas y fraudes ⚠️🕵️‍♂️
# - Registros más detallados 📝🔍
# - Mejora en la toma de decisiones 📈🤝
# - Descubrimientos científicos 🔬🧪
#
#
#
# Evidentemente, las aplicaciones y los beneficios potenciales del Big Data son amplios. Sin embargo, existen numerosos problemas que deben considerarse al adoptar enfoques de análisis de Big Data. Estos problemas deben entenderse y ponderarse frente a los beneficios anticipados para que se puedan generar decisiones y planes informados.

# %% [markdown]
# ### **Algunos conceptos importantes**
#
# **On-Premise:**
# - **Almacenamiento local:** En una solución "on-premise", los datos se almacenan en servidores y sistemas que están físicamente ubicados en las instalaciones de la organización.
# - **Control total:** La organización tiene un control completo sobre la infraestructura, los servidores y el entorno en el que se encuentran los datos.
# - **Seguridad y privacidad:** La seguridad depende de la infraestructura y medidas de seguridad implementadas por la organización, lo que puede requerir inversiones significativas en términos de seguridad cibernética y recursos humanos.
# - **Costos iniciales:** Se requiere una inversión inicial en hardware, servidores, infraestructura y personal para gestionar y mantener los sistemas.
# - **Escalabilidad limitada:** La escalabilidad puede ser más complicada y costosa, ya que se deben adquirir y configurar nuevos equipos físicos a medida que crecen los requisitos de datos.
# - **Acceso local:** El acceso a los datos suele limitarse a la red interna de la organización y puede requerir conexiones VPN para acceder de forma segura desde ubicaciones remotas.
#
# **Data Cloud (Nube de Datos):**
# - **Almacenamiento en la nube:** En una solución de "data cloud", los datos se almacenan en servidores remotos y gestionados por proveedores de servicios en la nube.
# - **Infraestructura gestionada:** La organización no es responsable de mantener la infraestructura física. El proveedor de la nube se encarga de la administración y el mantenimiento.
# - **Seguridad y privacidad:** Los proveedores de la nube ofrecen medidas de seguridad robustas y certificaciones para proteger los datos. Sin embargo, la confianza en la seguridad de la nube implica ceder cierto nivel de control a terceros.
# - **Costos escalonados:** Los costos suelen ser operativos en lugar de iniciales, con modelos de pago por uso. Puede ser más rentable a largo plazo, especialmente para empresas que experimentan cambios en sus necesidades de almacenamiento y cómputo.
# - **Escalabilidad flexible:** La nube permite escalar fácilmente los recursos según las necesidades cambiantes, ya que los proveedores pueden asignar recursos adicionales de manera rápida y eficiente.
# - **Acceso remoto:** Los datos pueden accederse desde cualquier ubicación con conexión a Internet, lo que facilita el trabajo remoto y la colaboración.
#
# La elección entre "on-premise" y "data cloud" depende de los objetivos, recursos y necesidades de seguridad de una organización. Las soluciones "on-premise" brindan un mayor control pero requieren inversiones significativas, mientras que las soluciones en la nube ofrecen flexibilidad y escalabilidad, a expensas de ceder cierto control sobre la infraestructura a terceros.

# %% [markdown]
# <span class="hljs-tag"><img src="https://edteam-media.s3.amazonaws.com/blogs/original/def59e91-b472-40dd-b9c4-cda7f79a3515.png" width="580">
#
# ## Las Mejores Empresas de Cloud Computing
#
# Lamejores empresas de Cloud Computing, ideales para ser contratadas debido a su eficiencia y competitividad en términos de computación en la nube, procesamiento y análisis de datos. Las herramientas y servicios que ofrecen son fundamentales para optimizar las operaciones empresariales de manera eficiente.
#
# 1.  [**Amazon Web Services (AWS)** 🌐🔧](https://aws.amazon.com/es/)
#    Amazon Web Services es una plataforma de Cloud Computing gestionada por Amazon. Es la plataforma más grande y ampliamente utilizada en todo el mundo, ofreciendo una variedad de herramientas y servicios que facilitan la administración de operaciones empresariales de manera efectiva. Algunas de estas herramientas incluyen:
#
#    - Amazon Elastic Compute Cloud
#    - Amazon Simple Storage Service
#    - Amazon Relational Database Service
#    - Amazon Virtual Private Cloud
#    - Amazon Lambda
#    - Amazon Elastic Block Store
#
# 2. [**Microsoft Azure** ☁️🔍](https://azure.microsoft.com/es-es)
#    Microsoft Azure es la plataforma de Cloud Computing de Microsoft. Ofrece servicios de computación, almacenamiento, análisis de datos y aprendizaje automático, entre otros. Destacan servicios como:
#
#    - Azure Virtual Machines
#    - Azure Storage
#    - Azure SQL Database
#    - Azure App Service
#    - Azure Cosmos DB
#
# 3. [**Google Cloud Platform (GCP)** ☁️🚀](https://cloud.google.com/?hl=es)
#    Google Cloud Platform es la solución de Google, conocida por su disponibilidad, escalabilidad y precio competitivo. Ofrece una amplia gama de servicios, como:
#
#    - Google Compute Engine
#    - Google Cloud Storage
#    - Google Cloud SQL
#    - Google BigQuery
#
# 4. [**IBM Cloud** ☁️🔑](https://cloud.ibm.com/)
#    IBM Cloud ofrece una amplia gama de servicios, incluyendo almacenamiento, computación, análisis y servicios integrados con herramientas existentes de IBM. Algunos servicios destacados son:
#
#    - IBM Watson Studio
#    - IBM Cloud Pak for Data
#    - IBM Cloud Pak for Security
#
#
# **Fuente:** [Tokio School](https://www.tokioschool.com/noticias/empresas-cloud-computing/)

# %% [markdown]
# ![texto del vínculo](https://holori.com/wp-content/uploads/2024/06/cloud-provider-market-share-up-to-Q2-2024-1024x691.jpg)

# %% [markdown]
# ## ¿Qué es el Big Data?
#
# Para que un conjunto de datos sea considerado como Big Data, debe poseer una o más características que requieran adaptación en el diseño y la arquitectura de la solución del entorno analítico. La mayoría de estas características de los datos fueron identificadas inicialmente por Doug Laney a principios de 2001, cuando publicó un artículo describiendo el impacto del volumen, la velocidad y la variedad de los datos de comercio electrónico en los almacenes de datos empresariales. A esta lista se ha añadido la veracidad para tener en cuenta la relación señal-ruido más baja de los datos no estructurados en comparación con las fuentes de datos estructurados. En última instancia, el objetivo es realizar un análisis de los datos de manera que se entreguen resultados de alta calidad de manera oportuna, lo que proporciona un valor óptimo a la empresa.
#
# Esta sección explora las cinco características del Big Data que pueden utilizarse para diferenciar los datos categorizados como "grandes" de otras formas de datos. Las cinco características del Big Data  se conocen comúnmente como los Cinco V:
# - Volumen (Volume)
# - Velocidad (Velocity)
# - Variedad (Variety)
# - Veracidad (Veracity)
# - Valor (Value)
#
# <span class="hljs-tag"><img src="https://datascience.uc.cl/images/las-5-v-bigdata.png" width="480">
#
#
# **Volumen**
# El volumen anticipado de datos que procesan las soluciones de Big Data es considerable y está en constante crecimiento. Los altos volúmenes de datos imponen demandas distintas en el almacenamiento y procesamiento de datos, así como procesos adicionales de preparación, curación y gestión de datos.
#
# Fuentes de datos típicas que son responsables de generar altos volúmenes de datos pueden incluir:
#
# * transacciones en línea, como puntos de venta y banca
# * experimentos científicos e investigaciones, como el Gran Colisionador de Hadrones y el telescopio Atacama Large Millimeter/Submillimeter Array
# * sensores, como sensores GPS, RFIDs, medidores inteligentes y telemetría
# * redes sociales, como Facebook y Twitter
#
# **Velocidad**
# En entornos de Big Data, los datos pueden llegar a velocidades rápidas y enormes conjuntos de datos pueden acumularse en períodos de tiempo muy cortos. Desde el punto de vista de una empresa, la velocidad de los datos se traduce en el tiempo que lleva procesar los datos una vez que ingresan en el perímetro de la empresa. Lidiar con el rápido flujo de datos requiere que la empresa diseñe soluciones de procesamiento de datos altamente elásticas y disponibles, así como capacidades de almacenamiento de datos correspondientes.
#
# Dependiendo de la fuente de datos, la velocidad no siempre puede ser alta. Por ejemplo, las imágenes de resonancia magnética (MRI) no se generan con tanta frecuencia como las entradas de registro de un servidor web con mucho tráfico. La velocidad de los datos cobra perspectiva al considerar que los siguientes volúmenes de datos pueden generarse fácilmente en un minuto dado: 350,000 tweets, 500 horas de metraje de video cargado en YouTube, 197 millones de correos electrónicos y 330 GB de datos de sensores de un motor a reacción.
#
#
# **Variedad**
# La variedad de datos se refiere a los múltiples formatos y tipos de datos que deben ser compatibles con las soluciones de Big Data. La variedad de datos plantea desafíos para las empresas en términos de integración, transformación, procesamiento y almacenamiento de datos.Dentro de la variedad se encuentran la clasificacion según el tipo de  datos estructurados en forma de transacciones financieras, datos semi-estructurados en forma de correos electrónicos y datos no estructurados en forma de imágenes.
#
# **Veracidad**
# La veracidad se refiere a la calidad o fidelidad de los datos. Los datos que ingresan en entornos de Big Data deben ser evaluados en cuanto a su calidad, lo que puede llevar a actividades de procesamiento de datos para resolver datos inválidos y eliminar el ruido. En relación con la veracidad, los datos pueden ser parte de la señal o del ruido en un conjunto de datos. El ruido es data que no se puede convertir en información y, por lo tanto, no tiene valor, mientras que las señales tienen valor y conducen a información significativa. Los datos con una alta relación señal-ruido tienen más veracidad que los datos con una relación más baja. Los datos que se adquieren de manera controlada, por ejemplo, a través de registros de clientes en línea, suelen contener menos ruido que los datos adquiridos a través de fuentes no controladas, como publicaciones en blogs. Por lo tanto, la relación señal-ruido de los datos depende de la fuente de los datos y su tipo.
#
#
# **Valor**
# El valor se define como la utilidad de los datos para una empresa. La característica de valor está intuitivamente relacionada con la característica de veracidad en el sentido de que cuanto mayor sea la fidelidad de los datos, más valor tendrá para el negocio. El valor también depende de cuánto tiempo lleva el procesamiento de datos, ya que los resultados del análisis tienen una vida útil; por ejemplo, una cotización de acciones con 20 minutos de retraso tiene poco o ningún valor para realizar una operación en comparación con una cotización que tiene 20 milisegundos de antigüedad.
# Como se demuestra, el valor y el tiempo están inversamente relacionados. Cuanto más tiempo se tarde en convertir los datos en información significativa, menos valor tendrá para un negocio. Los resultados obsoletos inhiben la calidad y la velocidad de la toma de decisiones informadas.

# %% [markdown]
# Los datos generados por humanos y por máquinas pueden provenir de una variedad de fuentes y representarse en diversos formatos o tipos. A Continuación veremos la variedad de tipos de datos que son procesados por las soluciones de Big Data. Los principales tipos de datos son:
#
# - Datos estructurados
# - Datos no estructurados
# - Datos semi-estructurados
#
# ![texto del vínculo](https://dgcloud.com.br/wp-content/uploads/2022/01/Estruturado-vs-Desestruturado.png)
#
# Estos tipos de datos se refieren a la organización interna de los datos y a veces se denominan formatos de datos. Aparte de estos tres tipos fundamentales de datos.
#
# **Datos Estructurados**
#
# Los datos estructurados se ajustan a un modelo de datos o esquema y a menudo se almacenan en forma de tablas. Se utilizan para capturar relaciones entre diferentes entidades y, por lo tanto, se almacenan principalmente en una base de datos relacional. Los datos estructurados son generados con frecuencia por aplicaciones empresariales y sistemas de información como los sistemas ERP y CRM. Debido a la abundancia de herramientas y bases de datos que admiten nativamente datos estructurados, rara vez requiere consideración especial en cuanto a procesamiento o almacenamiento. Ejemplos de este tipo de datos incluyen transacciones bancarias, facturas y registros de clientes.
#
# * Ejemplo: Información de una base de datos de clientes que incluye nombres, direcciones, números de teléfono y fechas de compra.
#
# * Formatos Comunes: Tablas en bases de datos relacionales (por ejemplo, SQL), hojas de cálculo (por ejemplo, Excel), archivos CSV (valores separados por comas).
#
# **Datos No Estructurados**
#
# Los datos que no se ajustan a un modelo de datos o esquema de datos se conocen como datos no estructurados. Se estima que los datos no estructurados representan el 80% de los datos dentro de cualquier empresa dada. Los datos no estructurados tienen una tasa de crecimiento más rápida que los datos estructurados. Esta forma de datos puede ser tanto textual como binaria, y a menudo se transmite a través de archivos que son autosuficientes y no relacionales. Un archivo de texto puede contener el contenido de varios tweets o publicaciones de blogs. Los archivos binarios suelen ser archivos multimedia que contienen datos de imágenes, audio o video. Técnicamente, tanto los archivos de texto como los binarios tienen una estructura definida por el formato del archivo en sí, pero este aspecto se pasa por alto y la noción de ser no estructurados se refiere al formato de los datos contenidos en el archivo en sí mismo.
#
# * Ejemplo: Comentarios de clientes en una plataforma de redes sociales que expresan opiniones sobre un producto.
#
# * Formatos Comunes: Texto libre en comentarios, publicaciones de redes sociales, contenido de blogs, imágenes, audio y video.
#
# **Datos Semi-Estructurados**
#
# Los datos semi-estructurados tienen un nivel definido de estructura y consistencia, pero no son de naturaleza relacional. En cambio, los datos semi-estructurados son jerárquicos o basados en gráficos. Este tipo de datos comúnmente se almacena en archivos que contienen texto.Los archivos XML y JSON son formas comunes de datos semi-estructurados. Debido a la naturaleza textual de estos datos y su conformidad con algún nivel de estructura, son más fáciles de procesar que los datos no estructurados.
#
# * Ejemplo: Información de productos en formato XML que incluye detalles de productos y atributos.
#
# * Formatos Comunes: Archivos XML (Lenguaje de Marcado Extensible) para datos jerárquicos, archivos JSON (Notación de Objetos JavaScript) para datos basados en atributos, archivos HTML (Lenguaje de Marcado de Hipertexto) con metadatos y contenido estructurado.
#
# *Tomemos una pausa de  15 minutos*

# %% [markdown]
# ## Parte 2
#
# ### Manipulación de datos en python

# %% [markdown]
# En este apartado tendremos enfoque en la  tarea de manipulación de datos en sus diversas formas: estructurados, no estructurados y semi-estructurados. Cada tipo de dato presenta desafíos únicos y oportunidades emocionantes en el mundo del análisis y la toma de decisiones.
#
# Comenzaremos por adentrarnos en el mundo de los datos estructurados, que siguen un esquema definido y se almacenan en tablas. Aprenderemos cómo utilizar herramientas como pandas en Python para organizar, filtrar y agregar datos, obteniendo información valiosa de conjuntos
# tabulares.
#
# #### **Datos estructurados**

# %%
import pandas as pd

# Crear un diccionario con datos de ejemplo
datos = {
    'Nombre': ['Ana', 'Juan', 'María', 'Carlos', 'Elena', 'Pedro', 'Laura', 'Sofía', 'Miguel', 'Luis'],
    'Edad': [25, 30, 28, 22, 35, 40, 27, 29, 31, 24],
    'Departamento': ['Ventas', 'TI', 'RRHH', 'Ventas', 'Finanzas', 'TI', 'RRHH', 'Finanzas', 'TI', 'Ventas'],
    'Salario': [50000, 60000, 55000, 45000, 70000, 75000, 52000, 58000, 62000, 48000]
}

# Crear el DataFrame a partir del diccionario
data_frame = pd.DataFrame(datos)

# Mostrar el DataFrame
display(data_frame)
# Out:
#    Nombre  Edad Departamento  Salario
# 0     Ana    25       Ventas    50000
# 1    Juan    30           TI    60000
# 2   María    28         RRHH    55000
# 3  Carlos    22       Ventas    45000
# 4   Elena    35     Finanzas    70000
# 5   Pedro    40           TI    75000
# 6   Laura    27         RRHH    52000
# 7   Sofía    29     Finanzas    58000
# 8  Miguel    31           TI    62000
# 9    Luis    24       Ventas    48000

# %%
# Filtrar empleados mayores de 30 años
empleados_mayores = data_frame[data_frame['Edad'] > 30]
print("\nEmpleados mayores de 30 años:")
display(empleados_mayores)

# Calcular el salario promedio por departamento
salario_promedio_por_departamento = data_frame.groupby('Departamento')['Salario'].mean()
print("\nSalario promedio por departamento:")
print(salario_promedio_por_departamento)
# Out:
# Empleados mayores de 30 años:
#    Nombre  Edad Departamento  Salario
# 4   Elena    35     Finanzas    70000
# 5   Pedro    40           TI    75000
# 8  Miguel    31           TI    62000
# Salario promedio por departamento:
# Departamento
# Finanzas    64000.000000
# RRHH        53500.000000
# TI          65666.666667
# Ventas      47666.666667
# Name: Salario, dtype: float64

# %% [markdown]
# `chunksize` es un parámetro que se utiliza en pandas al leer grandes conjuntos de datos desde archivos, como CSV o bases de datos, para dividir el proceso de lectura en fragmentos más pequeños. Esto es especialmente útil cuando el conjunto de datos no cabe completamente en la memoria y deseas procesar los datos en partes más manejables.
#
# Cuando se utiliza el parámetro `chunksize`, pandas lee y procesa el archivo en bloques de tamaño especificado en lugar de cargar todo el archivo de una vez. Cada bloque se trata como un DataFrame independiente que puedes procesar individualmente o combinar con otros bloques según tus necesidades.
#
# Aquí tienes un ejemplo de cómo usar `chunksize` al leer un archivo CSV con pandas:
#
# ```python
# import pandas as pd
#
# # Especifica el tamaño del chunk
# tamaño_chunk = 10000
#
# # Lee el archivo CSV en bloques de tamaño_chunk
# for chunk in pd.read_csv('archivo.csv', chunksize=tamaño_chunk):
#     # Realiza operaciones en el chunk actual
#     # Por ejemplo, puedes realizar cálculos o filtrar datos en cada chunk
#     print(chunk.shape)
# ```
#
# En este ejemplo, el archivo CSV se leerá en bloques de 10,000 filas cada uno. Dentro del bucle `for`, puedes realizar cualquier operación que necesites en cada chunk individual.
#
# El uso de `chunksize` es útil cuando trabajas con conjuntos de datos muy grandes y deseas procesarlos de manera eficiente y sin agotar la memoria disponible. Puedes aplicar funciones, filtros y otras operaciones en cada chunk y luego combinar los resultados según sea necesario.

# %%
for chunk in pd.read_csv('https://raw.githubusercontent.com/jazaineam1/BigData2026/main/Datos/datos_icfes.csv',encoding='latin-1', chunksize=100000):
    # Realiza operaciones en el chunk actual
    # Por ejemplo, puedes realizar cálculos o filtrar datos en cada chunk
    print(chunk.shape)
# Out:
# (100000, 8)
# (100000, 8)
# (100000, 8)
# (100000, 8)
# (100000, 8)
# (46212, 8)

# %%
# %%timeit
df_icfes=pd.read_csv('https://raw.githubusercontent.com/jazaineam1/BigData2023_2/main/Datos/datos_icfes.csv',encoding='latin-1',chunksize=10000)
# Out:
# 166 ms ± 17.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
df2=pd.read_csv('https://raw.githubusercontent.com/jazaineam1/BigData2023_2/main/Datos/datos_icfes.csv',encoding='latin-1')
# Out:
# 625 ms ± 113 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# `pandarallel` es una biblioteca de Python que permite paralelizar operaciones en pandas utilizando múltiples núcleos de CPU, lo que puede mejorar significativamente el rendimiento en operaciones que involucran grandes conjuntos de datos. A continuación, te explicaré cómo funciona `pandarallel`:
#
# 1. **Instalación:** Primero, debes instalar la biblioteca `pandarallel`. Puedes hacerlo usando el comando pip:
#
#    ```
#    pip install pandarallel
#    ```
#
# 2. **Importar y Configurar:** Después de instalar la biblioteca, debes importarla y configurarla antes de usarla. La configuración implica establecer el número de núcleos que deseas utilizar para las operaciones paralelas. Aquí hay un ejemplo de cómo hacerlo:
#
#    ```python
#    from pandarallel import pandarallel
#
#    pandarallel.initialize(nb_workers=4)  # Número de núcleos a utilizar
#    ```
#
# 3. **Uso en Operaciones:** Una vez que la biblioteca está configurada, puedes usarla en operaciones de pandas. La forma de usar `pandarallel` es utilizando el método `.parallel_apply()` en Series o DataFrames. Por ejemplo, supongamos que tienes un DataFrame `df` y deseas aplicar una función a una columna llamada 'columna_a':
#
#    ```python
#    def mi_funcion(valor):
#        # Operaciones que deseas realizar en paralelo
#        return resultado
#
#    df['nueva_columna'] = df['columna_a'].parallel_apply(mi_funcion)
#    ```
#
#    El método `.parallel_apply()` distribuirá automáticamente la aplicación de la función en paralelo en los núcleos que hayas configurado previamente.
#
# Recuerda que no todas las operaciones se benefician de la paralelización. Operaciones intensivas en cálculos o transformaciones suelen ser las más adecuadas para utilizar `pandarallel`.
#
# Es importante tener en cuenta que `pandarallel` utiliza la biblioteca `multiprocessing` internamente para lograr la paralelización. Sin embargo, la paralelización introduce cierto overhead, por lo que en operaciones pequeñas podría no resultar en una mejora significativa de rendimiento.

# %%
pip install pandarallel
# Out:
# Collecting pandarallel
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from pandarallel) (0.3.8)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.12/dist-packages (from pandarallel) (2.2.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from pandarallel) (5.9.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->pandarallel) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->pandarallel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->pandarallel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1->pandarallel) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1->pandarallel) (1.17.0)
# Building wheels for collected packages: pandarallel
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16674 sha256=a817c14a374d0ee9030d1c4de353a57c18d518550d48a04acac001d972478a8f
#   Stored in directory: /root/.cache/pip/wheels/46/f9/0d/40c9cd74a7cb8dc8fe57e8d6c3c19e2c730449c0d3f2bf66b5
# Successfully built pandarallel
# Installing collected packages: pandarallel
# Successfully installed pandarallel-1.6.5

# %%
from pandarallel import pandarallel

pandarallel.initialize(nb_workers=3)  # Número de núcleos a utilizar
# Out:
# INFO: Pandarallel will run on 3 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
df_icfes=pd.read_csv('https://raw.githubusercontent.com/jazaineam1/BigData2023_2/main/Datos/datos_icfes.csv',encoding='latin-1',chunksize=10000)
df_icfes

# %%
df_icfes.get_chunk(100)
# Out:
#    ESTU_DEPTO_RESIDE FAMI_ESTRATOVIVIENDA  PUNT_LECTURA_CRITICA  \
# 0          MAGDALENA            Estrato 3                    47
# 1             BOGOTÁ            Estrato 3                    60
# 2            BOLIVAR            Estrato 1                    66
# 3             BOGOTÁ            Estrato 3                    62
# 4             BOGOTÁ            Estrato 3                    63
# ..               ...                  ...                   ...
# 95             SUCRE            Estrato 1                    42
# 96              META            Estrato 3                    62
# 97      CUNDINAMARCA            Estrato 2                    52
# 98         SANTANDER            Estrato 1                    60
# 99           BOLIVAR            Estrato 1                    58
#
#     PUNT_MATEMATICAS  PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# 0                 48                37                        30           54
# 1                 65                54                        59           63
# 2                 57                41                        74           64
# 3                 54                61                        73           53
# 4                 57                55                        57           52
# ..               ...               ...                       ...          ...
# 95                47                50                        39           38
# 96                65                50                        46           45
# 97                28                45                        42           25
# 98                61                55                        51           48
# 99                48                44                        33           29
#
#     PUNT_GLOBAL
# 0           208
# 1           299
# 2           299
# 3           309
# 4           288
# ..          ...
# 95          220
# 96          275
# 97          202
# 98          280
# 99          222
#
# [100 rows x 8 columns]

# %%
df = pd.concat(df_icfes, ignore_index=True)

# %%
def cuadrado(valor):
    # Operaciones que deseas realizar en paralelo
    return valor**2

df['PUNT_LECTURA_CRITICA2'] = df['PUNT_LECTURA_CRITICA'].parallel_apply(cuadrado)
df
# Out:
#        ESTU_DEPTO_RESIDE FAMI_ESTRATOVIVIENDA  PUNT_LECTURA_CRITICA  \
# 0                CORDOBA            Estrato 2                    44
# 1                  CAUCA                    -                    32
# 2                BOLIVAR            Estrato 3                    40
# 3                  SUCRE            Estrato 2                    39
# 4                BOLIVAR            Estrato 2                    43
# ...                  ...                  ...                   ...
# 546107         ANTIOQUIA            Estrato 2                    76
# 546108            BOGOTÁ            Estrato 3                    75
# 546109            ARAUCA            Estrato 2                    72
# 546110         SANTANDER            Estrato 1                    59
# 546111            BOGOTÁ            Estrato 3                    76
#
#         PUNT_MATEMATICAS  PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# 0                     36                41                        37
# 1                     28                29                        32
# 2                     54                46                        42
# 3                     48                35                        31
# 4                     51                43                        44
# ...                  ...               ...                       ...
# 546107                78                65                        74
# 546108                73                72                        67
# 546109                83                71                        77
# 546110                61                54                        52
# 546111                73                72                        71
#
#         PUNT_INGLES  PUNT_GLOBAL  PUNT_LECTURA_CRITICA2
# 0              40.0          198                   1936
# 1              28.0          150                   1024
# 2              40.0          225                   1600
# 3              45.0          194                   1521
# 4              29.0          220                   1849
# ...             ...          ...                    ...
# 546107         58.0          360                   5776
# 546108         74.0          360                   5625
# 546109         72.0          377                   5184
# 546110         46.0          278                   3481
# 546111         74.0          365                   5776
#
# [546112 rows x 9 columns]

# %% [markdown]
# #### **Datos semi estructurados**
#
#
#
# **1. Identificación del formato:** Primero, determina el formato en el que están los datos semiestructurados, ya sea JSON, XML, HTML, CSV, etc. Esto te ayudará a elegir la herramienta o biblioteca adecuada para la lectura y análisis.
#
# **2. Selección de herramientas:** Utiliza bibliotecas o herramientas que sean compatibles con el formato de los datos. Por ejemplo, si tienes datos en formato JSON, puedes utilizar bibliotecas como `json` en Python, si son XML, puedes utilizar `xml.etree.ElementTree`.
#
# **3. Lectura de datos:** Utiliza las bibliotecas adecuadas para cargar los datos en una estructura que puedas manipular. Por ejemplo, en Python, puedes cargar datos JSON usando el módulo `json` o datos XML usando `xml.etree.ElementTree`.
#
# **4. Transformación y limpieza:** Los datos semiestructurados pueden tener campos opcionales, anidamientos y otros elementos que no siguen una estructura uniforme. Debes realizar una transformación y limpieza para estructurar los datos de manera coherente y prepararlos para el análisis.
#
# **5. Extracción de información:** Identifica los campos y elementos relevantes para tu análisis. Puedes acceder a estos campos utilizando las funciones o métodos proporcionados por las bibliotecas de lectura correspondientes.

# %%
import json
data = [
    {
        "nombre": "Juan",
        "apellido": "Pérez",
        "edad": 28,
        "departamento": "Ventas"
    },
    {
        "nombre": "María",
        "apellido": "Gómez",
        "edad": 32,
        "departamento": "Desarrollo"
    },
    {
        "nombre": "Carlos",
        "apellido": "López",
        "edad": 24,
        "departamento": "Marketing"
    }
]

# Escribir los datos en un archivo JSON
with open("empleados.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

# %%
with open("empleados.json", "r") as json_file:
    data = json.load(json_file)
# Imprimir los datos cargados
print(data)

# Acceder a la información de cada empleado
for empleado in data:
    print("Nombre:", empleado["nombre"])
    print("Apellido:", empleado["apellido"])
    print("Edad:", empleado["edad"])
    print("Departamento:", empleado["departamento"])
    print()
# Out:
# [{'nombre': 'Juan', 'apellido': 'Pérez', 'edad': 28, 'departamento': 'Ventas'}, {'nombre': 'María', 'apellido': 'Gómez', 'edad': 32, 'departamento': 'Desarrollo'}, {'nombre': 'Carlos', 'apellido': 'López', 'edad': 24, 'departamento': 'Marketing'}]
# Nombre: Juan
# Apellido: Pérez
# Edad: 28
# Departamento: Ventas
#
# Nombre: María
# Apellido: Gómez
# Edad: 32
# Departamento: Desarrollo
#
# Nombre: Carlos
# Apellido: López
# Edad: 24
# Departamento: Marketing

# %%
# Calcular la edad promedio de los empleados
edades = [empleado["edad"] for empleado in data]
edad_promedio = sum(edades) / len(edades)
print("Edad promedio:", edad_promedio)

# Contar el número de empleados por departamento
departamentos = [empleado["departamento"] for empleado in data]
departamento_contadores = {departamento: departamentos.count(departamento) for departamento in set(departamentos)}
print("Conteo de empleados por departamento:", departamento_contadores)
# Out:
# Edad promedio: 28.0
# Conteo de empleados por departamento: {'Marketing': 1, 'Ventas': 1, 'Desarrollo': 1}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#    nombre apellido  edad departamento
# 0    Juan    Pérez    28       Ventas
# 1   María    Gómez    32   Desarrollo
# 2  Carlos    López    24    Marketing

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# Generar datos de empleados
data = [
    {
        "nombre": "Juan",
        "apellido": "Pérez",
        "edad": 28,
        "departamento": "Ventas"
    },
    {
        "nombre": "María",
        "apellido": "Gómez",
        "edad": 32,
        "departamento": "Desarrollo"
    },
    {
        "nombre": "Carlos",
        "apellido": "López",
        "edad": 24,
        "departamento": "Marketing"
    },
    {
        "nombre": "Ana",
        "apellido": "Martínez",
        "edad": 30,
        "departamento": "Recursos Humanos"
    },
    {
        "nombre": "Luis",
        "apellido": "Rodríguez",
        "edad": 29,
        "departamento": "Ventas"
    },
    {
        "nombre": "Laura",
        "apellido": "Sánchez",
        "edad": 28,
        "departamento": "Desarrollo"
    },
    {
        "nombre": "Pedro",
        "apellido": "González",
        "edad": 26,
        "departamento": "Marketing"
    },
    {
        "nombre": "Sofía",
        "apellido": "López",
        "edad": 27,
        "departamento": "Ventas"
    }
]

# Crear el elemento raíz del XML
root = ET.Element("empleados")

# Iterar a través de los datos y agregar elementos al XML
for empleado_data in data:
    empleado = ET.SubElement(root, "empleado")
    for clave, valor in empleado_data.items():
        ET.SubElement(empleado, clave).text = str(valor)

# Crear el árbol XML
tree = ET.ElementTree(root)

# Escribir el árbol XML en un archivo
tree.write("empleados.xml")

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# Parsear el archivo XML
tree = ET.parse("empleados.xml")
root = tree.getroot()

# Crear una lista para almacenar los datos
data = []

# Iterar a través de los elementos del XML
for empleado in root.findall("empleado"):
    nombre = empleado.find("nombre").text
    apellido = empleado.find("apellido").text
    edad = int(empleado.find("edad").text)
    departamento = empleado.find("departamento").text
    data.append({"nombre": nombre, "apellido": apellido, "edad": edad, "departamento": departamento})

# Convertir la lista de datos a DataFrame
df = pd.DataFrame(data)

# Mostrar información básica del DataFrame
print("Información básica del DataFrame:")
print(df.info())

# Análisis de edad promedio por departamento
edad_promedio_por_departamento = df.groupby("departamento")["edad"].mean()
print("\nEdad promedio por departamento:")
print(edad_promedio_por_departamento)

# Análisis de la distribución de departamentos
conteo_departamentos = df["departamento"].value_counts()
print("\nConteo de empleados por departamento:")
print(conteo_departamentos)
# Out:
# Información básica del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        8 non-null      object
#  1   apellido      8 non-null      object
#  2   edad          8 non-null      int64
#  3   departamento  8 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 388.0+ bytes
# None
#
# Edad promedio por departamento:
# departamento
# Desarrollo          30.0
# Marketing           25.0
# Recursos Humanos    30.0
# Ventas              28.0
# Name: edad, dtype: float64
#
# Conteo de empleados por departamento:
# departamento
# Ventas              3
# Desarrollo          2
# Marketing           2
# Recursos Humanos    1
# Name: count, dtype: int64

# %% [markdown]
# #### Datos no estructurados
#
#
#
# **1. Preprocesamiento de datos:**
#    - Limpieza: Eliminar ruido y datos irrelevantes.
#    - Tokenización: Dividir el texto en unidades más pequeñas (palabras, frases, etc.).
#    - Normalización: Convertir texto a minúsculas, eliminar signos de puntuación, etc.
#    - Eliminación de stop words: Eliminar palabras comunes sin significado (por ejemplo, "el", "y", "en").
#    - Stemming y lematización: Reducir palabras a su forma base.
#
# **2. Análisis de texto:**
#    - Análisis de sentimiento: Determinar si el texto transmite emociones positivas, negativas o neutrales.
#    - Extracción de entidades: Identificar nombres de personas, lugares, fechas, etc.
#    - Detección de temas: Identificar temas clave presentes en el texto.
#    - Modelado de tópicos: Agrupar documentos en temas relacionados.
#
# **3. Procesamiento de imágenes y videos:**
#    - Extracción de características: Convertir imágenes en vectores numéricos.
#    - Detección de objetos: Identificar y localizar objetos en una imagen.
#    - Segmentación: Dividir una imagen en partes significativas.
#    - Reconocimiento de patrones: Identificar patrones o formas en las imágenes.
#
# **4. Procesamiento de audio:**
#    - Extracción de características: Convertir señales de audio en datos numéricos.
#    - Detección de voz: Identificar partes habladas en una grabación de audio.
#    - Reconocimiento de habla: Convertir el habla en texto escrito.
#
# **5. Análisis de redes sociales y web:**
#    - Análisis de redes sociales: Examinar patrones de interacción y opiniones en plataformas sociales.
#    - Web scraping: Recopilar datos relevantes de sitios web.

# %%
import re
from collections import Counter

texto_largo = """
La tecnología ha revolucionado nuestra sociedad en formas nunca antes imaginadas. La comunicación, la información y la forma en que hacemos negocios han experimentado transformaciones radicales.

Hoy en día, los dispositivos móviles son una extensión de nosotros mismos. Nos conectamos con personas de todo el mundo en un instante y compartimos ideas, imágenes y momentos a través de plataformas digitales.

La inteligencia artificial está en constante evolución y desafía lo que creíamos posible. Desde asistentes virtuales hasta sistemas de recomendación en línea, la IA está transformando la manera en que interactuamos con la tecnología y cómo vivimos nuestras vidas.

Los datos se han convertido en un recurso invaluable. Las empresas recopilan y analizan grandes cantidades de datos para comprender mejor a sus clientes, optimizar operaciones y tomar decisiones informadas. Sin embargo, esta riqueza de datos también plantea cuestiones sobre la privacidad y la seguridad.

El aprendizaje automático nos ha brindado herramientas para resolver problemas complejos y hacer predicciones precisas. Los algoritmos pueden detectar patrones en los datos y adaptarse a nuevas situaciones, lo que ha abierto la puerta a aplicaciones en una amplia gama de campos, desde la medicina hasta la conducción autónoma.

A medida que avanzamos en la era digital, es esencial abordar los desafíos éticos y sociales que surgen. La adicción a la tecnología, la desinformación en línea y la automatización de trabajos son temas que requieren atención cuidadosa y soluciones equitativas.

En resumen, la tecnología ha transformado nuestro mundo de maneras inimaginables. Si bien ha mejorado muchas áreas de nuestras vidas, también plantea interrogantes y dilemas. Como sociedad, debemos navegar por este nuevo territorio con responsabilidad y consideración.
"""

# Escribir el texto en un archivo
with open("texto_largo.txt", "w") as txt_file:
    txt_file.write(texto_largo)


# Leer el archivo de texto
with open("texto_largo.txt", "r") as txt_file:
    texto = txt_file.read()

# Contar palabras usando expresiones regulares
palabras = re.findall(r'\b\w+\b', texto.lower())
conteo_palabras = Counter(palabras)

# Mostrar las palabras más comunes
print("Palabras más comunes:")
for palabra, conteo in conteo_palabras.most_common(5):
    print(f"{palabra}: {conteo}")

# Contar oraciones
oraciones = re.split(r'[.!?]', texto)
conteo_oraciones = len([oracion for oracion in oraciones if oracion.strip() != ""])

# Mostrar el conteo de oraciones
print("\nTotal de oraciones:", conteo_oraciones)
# Out:
# Palabras más comunes:
# la: 19
# y: 15
# en: 13
# de: 10
# que: 7
#
# Total de oraciones: 16

# %%
import matplotlib.pyplot as plt
palabras = re.findall(r'\b\w+\b', texto.lower())
conteo_palabras = Counter(palabras)

# Obtener las palabras más comunes y sus conteos
palabras_comunes = [palabra for palabra, conteo in conteo_palabras.most_common(10)]
conteos = [conteo_palabras[palabra] for palabra in palabras_comunes]

# Crear un gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(palabras_comunes, conteos, color='skyblue')
plt.title('Palabras Más Comunes en el Texto')
plt.xlabel('Palabra')
plt.ylabel('Conteo')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Reto:**  ¿Cómo harías el análsis de este conjunto de [datos](https://www.datos.gov.co/Gastos-Gubernamentales/SECOP-Integrado/rpmr-utcd)?.
#
# Pueden revisar información sobre cómo en la página: https://dev.socrata.com/foundry/www.datos.gov.co/rpmr-utcd

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)

# %% [markdown]
# Por supuesto, aquí tienes un tutorial paso a paso sobre cómo utilizar la API de Socrata con los datos proporcionados, utilizando Python.
#
# ## Tutorial: Uso de la API Socrata con Python
#
# En este tutorial, aprenderemos cómo utilizar la API de Socrata para acceder a los datos del portal "Datos Abiertos Colombia". Utilizaremos Python y la biblioteca `requests` para realizar solicitudes a la API y procesar los datos.
#
# ### Paso 1: Importar las Bibliotecas
#
# En primer lugar, asegurémonos de tener la biblioteca `requests` instalada. Si no lo tienes, puedes instalarla con el siguiente comando:
#
# ```bash
# pip install requests
# ```
#
# Ahora, en tu script de Python, importa la biblioteca `requests`:
#
# ```python
# import requests
# ```
#
# ### Paso 2: URL de la API
#
# Visita el enlace que proporcionaste: [https://www.datos.gov.co/Gastos-Gubernamentales/SECOP-Integrado/rpmr-utcd](https://www.datos.gov.co/Gastos-Gubernamentales/SECOP-Integrado/rpmr-utcd). En la parte superior derecha de la página, encontrarás un botón que dice "API". Haz clic en él y copia la URL que aparece en la barra de direcciones.
#
# ### Paso 3: Realizar una Solicitud a la API
#
# Ahora, utilizaremos la URL de la API que copiamos en el paso anterior para hacer una solicitud GET y obtener los datos. También definiremos los parámetros que queremos incluir en la consulta.
#
# ```python
# # URL de la API
# url = "https://www.datos.gov.co/resource/rpmr-utcd.json"
#
# # Parámetros de la consulta
# params = {
#     "$limit": 10,  # Número máximo de registros a obtener
#     "$offset": 0,  # Índice de inicio
#     "$select": "nombre_de_la_entidad,nit_de_la_entidad,departamento_entidad,valor_contrato",  # Campos a seleccionar
# }
#
# # Realizar la solicitud GET
# response = requests.get(url, params=params)
#
# if response.status_code == 200:
#     data = response.json()
# else:
#     print("Error al acceder a la API:", response.status_code)
#     exit()
#
# ```
#
# ### Paso 4: Procesar los Datos
#
# Ahora que tenemos la respuesta de la API, procesaremos los datos utilizando la biblioteca `json` de Python para convertir la respuesta en un formato legible.
#
# ```python
# import json
#
# # Convertir la respuesta en formato JSON
# data = response.json()
#
# # Mostrar los primeros registros
# for item in data:
#     print(item)
# ```
#
# ### Paso 5: Analizar y Visualizar los Datos
#
# Si deseas realizar análisis más detallados o visualizar los datos, puedes usar bibliotecas como `pandas` o `matplotlib`. Por ejemplo, aquí hay un ejemplo simple utilizando `pandas` para crear un DataFrame y mostrar los primeros registros:
#
# ```python
# import pandas as pd
#
# # Crear un DataFrame
# df = pd.DataFrame(data)
#
# # Mostrar los primeros registros
# print(df.head())
# ```
#
# Este tutorial te ha guiado a través de los pasos clave para utilizar la API de Socrata con Python. Puedes personalizar los parámetros de la consulta según tus necesidades y seguir explorando y analizando los datos. ¡Diviértete explorando y analizando los datos abiertos!

# %%
import requests
#pruebe este codigo acá
#realice una visualización de una variable que le resulte interesante
#haga un breve análisis
# URL de la API
url = "https://www.datos.gov.co/resource/rpmr-utcd.json"

# Parámetros de la consulta
params = {
    "$limit": 10,  # Número máximo de registros a obtener
    "$offset": 0,  # Índice de inicio
    "$select": "nombre_de_la_entidad,nit_de_la_entidad,departamento_entidad,valor_contrato",  # Campos a seleccionar
}

# Realizar la solicitud GET
response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
else:
    print("Error al acceder a la API:", response.status_code)
    exit()

# %%
import json

# Convertir la respuesta en formato JSON
data = response.json()

# Mostrar los primeros registros
for item in data:
    print(item)
# Out:
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'ANTIOQUIA - E.S.E. HOSPITAL MARCO FIDEL SUAREZ - BELLO', 'nit_de_la_entidad': '890985703', 'departamento_entidad': 'Antioquia', 'valor_contrato': '4974000'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}
# {'nombre_de_la_entidad': 'DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍSTICA (DANE)', 'nit_de_la_entidad': '899999027', 'departamento_entidad': 'Bogotá D.C.', 'valor_contrato': '6476892'}

# %%
import pandas as pd

# Crear un DataFrame
df = pd.DataFrame(data)

# Mostrar los primeros registros
print(df.head())
# Out:
#                                 nombre_de_la_entidad nit_de_la_entidad  \
# 0  DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍ...         899999027
# 1  DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍ...         899999027
# 2  DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍ...         899999027
# 3  DEPARTAMENTO ADMINISTRATIVO NACIONAL DE ESTADÍ...         899999027
# 4  ANTIOQUIA - E.S.E. HOSPITAL MARCO FIDEL SUAREZ...         890985703
#
#   departamento_entidad valor_contrato
# 0          Bogotá D.C.        6476892
# 1          Bogotá D.C.        6476892
# 2          Bogotá D.C.        6476892
# 3          Bogotá D.C.        6476892
# 4            Antioquia        4974000

# %% [markdown]
# ## Conclusiones
#
# Por supuesto, aquí tienes cinco conclusiones claras y relevantes basadas en la información que proporcionaste:
#
# 1. **Impacto de la Era de la Información:** En la actual "Era de la Información", las empresas deben aprovechar el análisis de big data para tomar decisiones más informadas y estratégicas. La abundancia de datos y la rápida evolución tecnológica han transformado la forma en que las organizaciones operan y compiten.
#
# 2. **Importancia de los Cinco V del Big Data:** La gestión efectiva del big data requiere abordar los cinco V: volumen, velocidad, variedad, veracidad y valor. Estas características distinguen los datos como "grandes" y plantean desafíos específicos que deben abordarse para aprovechar todo su potencial.
#
# 3. **Diversidad de Tipos de Datos:** Los datos estructurados, no estructurados y semi-estructurados son fundamentales en el análisis de big data. Comprender estos tipos de datos es esencial para procesarlos eficazmente y extraer conocimientos significativos. Los datos no estructurados, en particular, representan una gran parte del panorama de datos empresariales.
#
# 4. **Elección entre On-Premise y Data Cloud:** Las empresas deben considerar cuidadosamente si optar por soluciones de almacenamiento y procesamiento "on-premise" o en la nube. Cada enfoque tiene sus propias ventajas y desafíos en términos de control, seguridad, escalabilidad y costos, y la elección debe basarse en las necesidades y objetivos de la organización.
#
#
#
# 5. **Ingesta de Datos en Python para Diferentes Tipos:** Además de comprender los tipos de datos, es esencial saber cómo realizar la ingesta de datos en diferentes formatos en Python. Para datos estructurados, semi-estructurados y no estructurados, Python ofrece bibliotecas y herramientas específicas que permiten a las empresas extraer, transformar y cargar (ETL) datos de manera eficiente. Explorar y utilizar bibliotecas como pandas, re y json en Python facilita la preparación y el procesamiento de datos en diversos formatos, lo que es fundamental para el análisis de big data.

# %% [markdown]
# # **Ejercicio en tiempo libre:**
#  Fortaleciendo tus Habilidades en Python: Practica Constante
#
# ## **Acceso a los Recursos**
#
# Hemos recopilado una serie de cuadernos de práctica para ustedes. Pueden acceder a estos recursos en este [enlace](https://github.com/jazaineam1/BigData2023_2/blob/main/Practica%20Python-20230216.zip). ¡No duden en descargarlos y explorarlos desde donde se encuentren!
#
# Recuerden, la práctica es el camino hacia la maestría. A medida que se sumerjan en los desafíos y ejercicios de estos cuadernos, verán cómo sus habilidades en Python crecerán y se fortalecerán.

# %% [markdown]
# **Gracias**
