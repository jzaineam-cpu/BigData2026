# %% [markdown]
# <a href="https://colab.research.google.com/github/jazaineam1/BigData2023_2/blob/main/Cuadernos/4_5_Pr%C3%A1ctica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Reto 1: News Feed Processor***
#
# ## ***Universidad Central***
# >## **Facultad de Ingeniería y Ciencias Básicas.**
# >## ***Maestría en analítica de datos***
# ![Imágen1](https://www.ucentral.edu.co/themes/ucentral/img/template/Universidad%20Central.png)
#
#
# >## ***Big Data.***

# %% [markdown]
# Un sitemap de una página web es básicamente un mapa o una guía que enumera todas las páginas importantes de un sitio web. Se puede ver  como un índice o tabla de contenidos que le dice a los motores de búsqueda y a los visitantes dónde está cada pieza de contenido en tu sitio. Los sitemaps son especialmente útiles para sitios web grandes, con muchas páginas, o para aquellos con contenido que no está fácilmente accesible a través de enlaces.
#
# ### Propósitos y Beneficios de un Sitemap
#
# 1. **Mejora la Indexación por Motores de Búsqueda**:
#    - Los sitemaps son una herramienta crucial para los motores de búsqueda como Google. Ayudan a los rastreadores de estos motores a encontrar y entender el contenido de tu sitio web. Cuando envías un sitemap a un motor de búsqueda, básicamente le estás diciendo: "Aquí están las páginas de mi sitio web, por favor inclúyelas en tu índice".
#
# 2. **Facilita la Navegación**:
#    - Para los visitantes del sitio, un sitemap puede actuar como una herramienta de navegación rápida, permitiéndoles encontrar la información que buscan sin tener que navegar por todo el sitio.
#
# 3. **Organización y Estructura del Sitio Web**:
#    - Crear un sitemap te obliga a pensar en la estructura y organización de tu sitio, lo cual es crucial para una buena experiencia de usuario y SEO (optimización para motores de búsqueda).
#
# 4. **Identificación de URLs y Contenido**:
#    - Los sitemaps permiten a los motores de búsqueda identificar rápidamente las URLs de tu sitio y cualquier contenido actualizado, lo cual es esencial para sitios con contenido que cambia frecuentemente.
#
# ### Tipos de Sitemaps
#
# 1. **Sitemap XML**:
#    - Es el tipo más común de sitemap. Está formateado de manera que los motores de búsqueda pueden leer e interpretar fácilmente el archivo. Los sitemaps XML listan las URLs de un sitio y pueden incluir información adicional como la última fecha de actualización, la frecuencia de cambios y la importancia de las URLs.
#
#       revisa el [enlace](https://www.eltiempo.com/robots.txt)
#
#
# 2. **Sitemaps de Imágenes y Vídeos**:
#    - Para sitios que son ricos en contenido multimedia, puedes tener sitemaps específicos que ayudan a los motores de búsqueda a encontrar tus imágenes y videos más fácilmente.
#
#    revisa el [enlace](https://www.youtube.com/feeds/videos.xml?channel_id=UCw7Bz6EHxlnOoBUBlJZCWCw)

# %% [markdown]
# Revisa el sitemap [https://www.youtube.com/sitemaps/sitemap.xml](https://www.youtube.com/sitemaps/sitemap.xml) y trata de leer la información relacionada a la primer noticia que encuentres usando lenguaje python

# %%
import requests
from bs4 import BeautifulSoup

# URL del artículo
url = 'https://www.eltiempo.com/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931'

# Realizar la solicitud HTTP para obtener el contenido de la página
respuesta = requests.get(url)

# Parsear el contenido HTML con BeautifulSoup
soup = BeautifulSoup(respuesta.content, 'html.parser')

# Buscar el contenido del artículo
# Nota: Deberás ajustar el selector según la estructura del HTML de la página
contenido_articulo = soup.find_all('p', class_='contenido')

print(contenido_articulo)
# Out:
# [<p class="contenido" id="p848931-m1754-1753-1755"><b>Nairo Quintana</b>, de 1,68 metros de estatura, se agigantó entre el 9 de mayo y el 1 de junio del 2014. El ciclista boyacense, por entonces una revelación mundial tras el subcampeonato en el Tour de Francia de 2013, le dio a Colombia su segundo título en una de las tres grandes, luego de la Vuelta a España que ganó ‘Lucho’ Herrera en 1987. El país, lleno de emoción, vibró con el triunfo de ‘Nairoman’ en el Giro de Italia. Y lo hizo gracias al apasionado relato del hombre que ha narrado durante los últimos años las grandes hazañas del ciclismo colombiano:<b> Mario Sabato</b>.</p>, <p class="contenido" id="p848931-m1843-3-1844">Argentino de nacimiento, pero colombiano por convicción, Sabato ha sido quien les ha dado voz a los triunfos de Egan y Nairo, los embalajes de Gaviria y Molano, los triunfos de Mariana Pajón, las escaladas de Sergio Higuita, las luchas de Rigoberto Urán y los golpes sobre la mesa de Santiago Buitrago, Einer Rubio y tantos más. <b>Su relato, una marca registrada durante 15 años en la cadena internacional ESPN, migra ahora a RCN</b>, el canal con el que ayer debutó en los nacionales de ciclismo y en el que espera seguir narrando las batallas de los ‘escarabajos’.</p>, <p class="contenido" id="p848931-m1855-5-1856">La verdad que es un desafío muy importante, es un desafío muy grande para mi carrera venir a Colombia. Yo estuve 15 años en Espn y, como puse el otro día cuando me despedía, fui muy feliz, crecí muchísimo como persona y como profesional, pero, bueno, cuando me propusieron este reto era como una combinación de todo lo que yo quería hacer porque yo amo narrar las carreras internacionales, las mejores carreras del mundo, pero también tenía una deuda pendiente porque yo digo: ‘Vengo siempre a Colombia 10, 12 veces al año y nunca pude narrar una carrera colombiana’.</p>, <p class="contenido" id="p848931-m1867-7-1868">Sí, cuando Andrea Guerrero (gerente de Deportes en RCN) me dice: ‘Mira, Mario, vamos a tener Giro, Tour, Vuelta, Olímpicos, bla bla bla bla, todas las carreras del calendario internacional’, dije: ‘Buenísimo, okay, lo mismo que yo hago’, y me dice: ‘Noo, pero también vamos a tener Vuelta a Colombia, Clásico RCN…’, ahí yo digo: ‘Ufff, qué interesante’, porque como que yo adentro mío tenía esa deuda pendiente y, bueno, se combinó todo de una manera perfecta y acá estoy como el nuevo narrador de ciclismo de RCN, que para mí es un placer muy grande.</p>, <p class="contenido" id="p848931-m1879-9-1880">Bueno, yo tengo mi familia, mi tío Carlos Reybaud, que fue ciclista, que corrió los Juegos Olímpicos, que fue campeón argentino varias veces y a raíz de seguirlo a él, si bien nosotros en Argentina nacemos con una pelota de fútbol en la cabeza porque es así, ¿eh? (risas), los sábados eran de ir a la cancha a ver a mi querido Sportivo Italiano, de la Cuarta División de Argentina, y los domingos de ir a ver a mi tío correr en el circuito de Loma, de Bellavista… entonces empecé a forjar esa pasión por el ciclismo. Yo siempre digo que es imposible no enamorarse del ciclismo. Y, bueno, desarrollé la pasión viniendo de un país donde el ciclismo la verdad que es muy poco, por no decir casi nada, difundido lamentablemente.</p>, <p class="contenido" id="p848931-m1891-11-1892">Duré un día nada más porque es demasiado difícil el ciclismo. Yo lo intenté, me subí por única vez en serio a tratar de ser ciclista en la pista que lleva el nombre de mi abuelo, Diego Reybaud, pero la bicicleta de pista, no sé si la gente sabe, pero no tiene frenos, son de piñón fijo, y fue tan difícil…. cuando me quedé en medio de un pelotón, con tantos ciclistas alrededor, dije ‘No…’. Logré bajarme de la bicicleta y sentí que era imposible. Yo, desde ese momento, con 12 o 13 años, dije: es muy difícil ser ciclista. O sea, a partir de ahí, mi admiración creció a niveles como los que tengo hoy por los ciclistas… que están en el deporte más lindo del mundo, pero a la vez en el más ...

# %% [markdown]
# b
#
# | Titulo | Fecha | Contenido |
# |--------|-------|-----------|
# | Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambió la vida' | [Fecha de la noticia] | [Contenido de la noticia] |

# %%
# Ingrese su código acá

# %% [markdown]
# Feeds: En el contexto de la web, los "feeds" son canales de información que proporcionan actualizaciones periódicas sobre ciertos temas. Estos pueden estar en formatos como RSS o Atom. Cada noticia en tu XML puede tener un enlace a un feed (posiblemente en formato JSON) que contiene detalles más específicos sobre esa noticia.
#
# revisa [https://www.eltiempo.com/servicios/feeds/articulo/848931](https://www.eltiempo.com/servicios/feeds/articulo/848931)

# %%
import pandas as pd
from datetime import datetime
import pytz
import json


zona_horaria = pytz.timezone('America/Bogota')

feed_url = 'https://www.eltiempo.com/servicios/feeds/articulo/848931'

# Realizar una petición GET a la URL del feed
feed_response = requests.get(feed_url)
data_rows=[]
# Verificar si la respuesta es exitosa
if feed_response.status_code == 200:
    # Parsear el contenido obtenido como JSON
    data = json.loads(feed_response.content)

    required_keys = ['id', 'title', 'lead', 'editor', 'author', 'content']
    if all(key in data['data'] for key in required_keys):
        # Extraer los datos requeridos del JSON
        id = data['data']['id']
        title = data['data']['title']
        lead = data['data']['lead']
        editor = data['data']['editor']
        author = data['data']['author']
        timestamp = data['data']['timestamp']
        fecha_utc = datetime.utcfromtimestamp(timestamp).replace(tzinfo=pytz.utc).astimezone(zona_horaria).strftime('%Y-%m-%d %H:%M:%S %Z')
        # Filtrar el contenido para obtener sólo el texto
        content = " ".join([BeautifulSoup(cont['content'], 'html.parser').get_text() for cont in data['data']['content'] if cont['type'] == 'text' and cont['content'].strip() != ''])

        # Prepara la fila de datos
        data_rows.append((id, title, lead, editor, author, content, fecha_utc, feed_url))
column_names = ["id", "title", "lead", "editor", "author", "content", "publication_date", "url"]
df=pd.DataFrame(data_rows,columns=column_names)
df
# Out:
#        id                                              title  \
# 0  848931  Mario Sabato se confiesa en Colombia: 'El triu...
#
#                                                 lead  \
# 0  El narrador argentino, el más colombiano de to...
#
#                               editor                             author  \
# 0  ANDRÉS FELIPE BALAGUERA SARMIENTO  ANDRÉS FELIPE BALAGUERA SARMIENTO
#
#                                              content         publication_date  \
# 0  Nairo Quintana, de 1,68 metros de estatura, se...  2024-01-26 23:59:19 -05
#
#                                                  url
# 0  https://www.eltiempo.com/servicios/feeds/artic...

# %% [markdown]
# **Ejercicio 2** (7 min)
#
# Extraiga la información de las primeras 5 noticias y continue con la información en un dataframe  usando los feeds:

# %%
# @title
ids=[848928,848876,848927]
for id in ids:
  feed_url = f'https://www.eltiempo.com/servicios/feeds/articulo/{id}'

  # Realizar una petición GET a la URL del feed
  feed_response = requests.get(feed_url)
  # Verificar si la respuesta es exitosa
  if feed_response.status_code == 200:
      # Parsear el contenido obtenido como JSON
      data = json.loads(feed_response.content)

      required_keys = ['id', 'title', 'lead', 'editor', 'author', 'content']
      if all(key in data['data'] for key in required_keys):
          # Extraer los datos requeridos del JSON
          id = data['data']['id']
          title = data['data']['title']
          lead = data['data']['lead']
          editor = data['data']['editor']
          author = data['data']['author']
          timestamp = data['data']['timestamp']
          fecha_utc = datetime.utcfromtimestamp(timestamp).replace(tzinfo=pytz.utc).astimezone(zona_horaria).strftime('%Y-%m-%d %H:%M:%S %Z')
          # Filtrar el contenido para obtener sólo el texto
          content = " ".join([BeautifulSoup(cont['content'], 'html.parser').get_text() for cont in data['data']['content'] if cont['type'] == 'text' and cont['content'].strip() != ''])

          # Prepara la fila de datos
          data_rows.append((id, title, lead, editor, author, content, fecha_utc, feed_url))

# %%
# @title
df=pd.DataFrame(data_rows,columns=column_names)
df
# Out:
#        id                                              title  \
# 0  848931  Mario Sabato se confiesa en Colombia: 'El triu...
# 1  848928  Evite que la salud de su hijo se afecte por el...
# 2  848876  Programación deportiva para el sábado 27 de enero
# 3  848927  Campaña Petro: el acta y la escritura que la F...
#
#                                                 lead  \
# 0  El narrador argentino, el más colombiano de to...
# 1  Una carga exagerada puede lastimar la estructu...
# 2  Fútbol colombiano, de Inglaterra, España y Abi...
# 3  Allí consta que donaron plata para apoyar la c...
#
#                               editor                             author  \
# 0  ANDRÉS FELIPE BALAGUERA SARMIENTO  ANDRÉS FELIPE BALAGUERA SARMIENTO
# 1                 MATEO CHACÓN ORDUZ                 MATEO CHACÓN ORDUZ
# 2              LISANDRO ABEL RENGIFO              LISANDRO ABEL RENGIFO
# 3               UNIDAD INVESTIGATIVA               UNIDAD INVESTIGATIVA
#
#                                              content         publication_date  \
# 0  Nairo Quintana, de 1,68 metros de estatura, se...  2024-01-26 23:59:19 -05
# 1  Es común ver en la calle a los niños, niñas y ...  2024-01-26 23:35:17 -05
# 2  WIN SPORTS +4 p.m.: fútbol colombiano, Santa F...  2024-01-26 23:33:07 -05
# 3  El lunes, 22 de enero, la sede de la Federació...  2024-01-26 23:30:00 -05
#
#                                                  url
# 0  https://www.eltiempo.com/servicios/feeds/artic...
# 1  https://www.eltiempo.com/servicios/feeds/artic...
# 2  https://www.eltiempo.com/servicios/feeds/artic...
# 3  https://www.eltiempo.com/servicios/feeds/artic...

# %% [markdown]
# Ahora leeremos la información de los ids directamente de https://www.eltiempo.com/sitemap-articles-current.xml

# %%
import re

url = 'https://www.eltiempo.com/sitemap-articles-current.xml'
session = requests.Session()

# Realizar solicitud inicial
response = session.get(url)
soup = BeautifulSoup(response.content, 'lxml')
sitemap_urls = [loc.text for loc in soup.find_all('loc')]

sitemap_urls
ids =[  re.search(r'\d+$', sitemap_url) for sitemap_url in sitemap_urls ]
ids= [int(match.group()) for match in ids if match]
print(len(ids))
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 989

# %% [markdown]
# **Ejercicio 3** (10 min)
#
# Extraiga la información de las primeras 100 noticias y continue con la información en un dataframe  usando los feeds:

# %% [markdown]
# Mira el siguiente código

# %%
import concurrent.futures
import time
import random

# Función que simula la descarga de contenido de una URL
def download_content(url):
    # Simula la duración de la descarga
    download_duration = 10
    print(f"Descargando desde {url} (duración: {download_duration} segundos)")
    time.sleep(download_duration)
    return f"Contenido de {url} descargado."

# Lista de URLs ficticias
urls = [
    "http://sitio1.com/data",
    "http://sitio2.com/data",
    "http://sitio3.com/data",
    "http://sitio4.com/data",
    "http://sitio5.com/data"
]

# Usamos ThreadPoolExecutor para descargar el contenido de las URLs en paralelo
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Mapeamos la función 'download_content' a cada URL
    results = list(executor.map(download_content, urls))

# Imprimimos los resultados
for result in results:
    print(result)
# Out:
# Descargando desde http://sitio1.com/data (duración: 10 segundos)Descargando desde http://sitio2.com/data (duración: 10 segundos)
# Descargando desde http://sitio3.com/data (duración: 10 segundos)
# Descargando desde http://sitio4.com/data (duración: 10 segundos)
#
# Descargando desde http://sitio5.com/data (duración: 10 segundos)
# Contenido de http://sitio1.com/data descargado.
# Contenido de http://sitio2.com/data descargado.
# Contenido de http://sitio3.com/data descargado.
# Contenido de http://sitio4.com/data descargado.
# Contenido de http://sitio5.com/data descargado.

# %% [markdown]
# El método `ThreadPoolExecutor.map` del módulo `concurrent.futures` en Python es una herramienta poderosa para ejecutar operaciones en paralelo. Es especialmente útil cuando tienes una función que quieres ejecutar con diferentes argumentos de manera concurrente. Aquí te doy una clase sobre cómo funciona `ThreadPoolExecutor.map` y cómo se usa en el contexto de tu script:
#
# ### 1. ¿Qué es `ThreadPoolExecutor`?
#
# `ThreadPoolExecutor` es una clase en el módulo `concurrent.futures` que proporciona una interfaz de alto nivel para ejecutar llamadas a funciones de manera asincrónica (es decir, de forma paralela o concurrente). Utiliza un pool de hilos (threads) para ejecutar las llamadas a funciones, lo que permite realizar múltiples operaciones al mismo tiempo.
#
# ### 2. ¿Qué hace el método `.map`?
#
# El método `.map` es similar al `map` integrado de Python, pero está diseñado para ejecutar las funciones en paralelo utilizando el pool de hilos de `ThreadPoolExecutor`. Lo que hace es tomar una función y un iterable (como una lista), y luego aplicar esa función a cada elemento del iterable. La gran ventaja aquí es que cada llamada a la función se ejecuta en un hilo separado, lo que permite que las operaciones se realicen de manera concurrente.
#
# ### 3. ¿Cómo funciona en tu script?
#
# En tu script, `ThreadPoolExecutor.map` se utiliza para aplicar la función `download_content` a cada URL en la lista `urls`. Esto es lo que sucede:
#
# - **Inicialización**: `ThreadPoolExecutor` se inicializa utilizando el bloque `with`, lo que garantiza que todos los hilos se cierren correctamente al finalizar las operaciones.
#
# - **Aplicación de la Función**: `executor.map(download_content, urls)` aplica `download_content` a cada elemento en `urls`. Bajo el capó, `ThreadPoolExecutor` asigna cada llamada a la función a un hilo diferente en su pool de hilos.
#
# - **Ejecución Concurrente**: Las funciones se ejecutan en paralelo. Si tienes, por ejemplo, 5 URLs y un pool de 5 hilos, las 5 descargas podrían, en teoría, suceder al mismo tiempo.
#
# - **Recopilación de Resultados**: `executor.map` devuelve un iterador que se convierte en una lista. Los resultados se devuelven en el orden en que se pasaron las tareas, es decir, el primer resultado corresponde al primer elemento en `urls`, y así sucesivamente.
#
# - **Impresión de Resultados**: Al final, imprimes los resultados, que son los valores devueltos por `download_content` para cada URL.
#
# ### 4. Ventajas de usar `ThreadPoolExecutor.map`
#
# - **Concurrencia**: Permite realizar múltiples operaciones de I/O (como solicitudes de red) de manera más eficiente, ya que no estás esperando a que cada operación se complete antes de iniciar la siguiente.
#
# - **Facilidad de Uso**: Proporciona una forma sencilla de convertir un bucle que procesa elementos de manera secuencial en un conjunto de operaciones concurrentes, con mínimos cambios en el código.
#
# - **Gestión de Recursos**: El manejo de los hilos y su ciclo de vida se gestionan automáticamente, lo que reduce el riesgo de errores relacionados con la concurrencia.

# %% [markdown]
# ¿Y esto en qué ayuda?

# %%
# Función para procesar cada feed
def fetch_feed_data(sitemap_url):
    feed_url = f'https://www.eltiempo.com/servicios/feeds/articulo/{sitemap_url}'
    feed_response = session.get(feed_url)
    if feed_response.status_code == 200:
        data = feed_response.json()
        timestamp = data['data']['timestamp']
        fecha_utc = datetime.utcfromtimestamp(timestamp).replace(tzinfo=pytz.utc).astimezone(zona_horaria).strftime('%Y-%m-%d %H:%M:%S %Z')
        content = " ".join([BeautifulSoup(cont['content'], 'html.parser').get_text() for cont in data['data']['content'] if cont['type'] == 'text' and cont['content'].strip() != ''])
        primer = BeautifulSoup(next((item['content'] for item in data['data']['content'] if item['type'] == 'text'), None),"html.parser").get_text()
        url = feed_url
        content = " ".join([BeautifulSoup(cont['content'], 'html.parser').get_text() for cont in data['data']['content'] if cont['type'] == 'text' and cont['content'].strip() != ''])
        thumbnail = data['data'].get('image', '')
        return (data['data']['id'], url, primer, data['data']['title'], data['data']['author'], data['data']['section'].split("/")[0].capitalize(), content,thumbnail, fecha_utc)
    return None

# %%
fetch_feed_data(848928)
# Out:
# (848928,
#  'https://www.eltiempo.com/servicios/feeds/articulo/848928',
#  'Es común ver en la calle a los niños, niñas y adolescentes llevando sobre sus hombros sendos morrales. Incluso, seguramente, en un ataque de ternura, haya mencionado una frase como esta: “¡Mira qué lindo ese niño! Esa maleta es más grande que él”.Pero, aunque a primera vista sea una escena enternecedora, la verdad es que esos menores podrían estar llevando a sus espaldas un peso mucho más alto del que debería. De hecho, esto es mucho más probable de lo que se pueda imaginar. Un estudio de la Universidad Manuela Beltrán analizó las maletas y su contenido encontró que casi la totalidad de los estudiantes suele cargar un peso más alto del recomendado, lo que a largo plazo afectaría su salud.',
#  'Evite que la salud de su hijo se afecte por el peso de la maleta escolar',
#  'MATEO CHACÓN ORDUZ',
#  'Vida',
#  'Es común ver en la calle a los niños, niñas y adolescentes llevando sobre sus hombros sendos morrales. Incluso, seguramente, en un ataque de ternura, haya mencionado una frase como esta: “¡Mira qué lindo ese niño! Esa maleta es más grande que él”.Pero, aunque a primera vista sea una escena enternecedora, la verdad es que esos menores podrían estar llevando a sus espaldas un peso mucho más alto del que debería. De hecho, esto es mucho más probable de lo que se pueda imaginar. Un estudio de la Universidad Manuela Beltrán analizó las maletas y su contenido encontró que casi la totalidad de los estudiantes suele cargar un peso más alto del recomendado, lo que a largo plazo afectaría su salud. Expertos de las facultades de Biomédica y Terapia Ocupacional de esta institución encontraron que un niño o una niña de alrededor de los 7 años de edad y un peso de 30 kilos, lo máximo que debería llevar a su espalda es un peso de 2 kilogramos, según explicó Diana Gutiérrez, ingeniera biomédica y una de las autoras de la investigación.Lo anterior es muy importante, especialmente si se tiene en cuenta que “el tiempo al que el niño somete su cuerpo a transportar este peso es de 400 horas anuales”, apunta la experta. Pero, entonces, ¿cuáles deben ser los parámetros de una maleta que no afecte la salud de nuestros hijos?Al analizar maletas, el estudio encontró que en promedio los niños cargan hasta 7,5 kilos en elementos como cuatro libros, cuatro cuadernos, una cartuchera, una lonchera, un juguete o un balón. Esto incluso entre los más pequeños, por lo que hay casos en que se cuadriplica el peso recomendado.Por el contrario, los expertos recomiendan seguir una regla simple: la maleta no debe pesar más del 10 por ciento del peso corporal del estudiante, procurando que el límite sea de 6 kilogramos.En otras palabras, si el alumno pesa 40 kilos, su maleta deberá pesar hasta 4 kilos. A esto se suman algunas condiciones físicas de los morrales, como que la maleta cubra toda la espalda, procurar comprar maletines con dos tiras, en lugar de una, con el fin de distribuir el peso y no recargar un solo hombro, que las hombreras sean anchas y acolchadas, y que cuenten con un espaldar también cómodo, que proteja la espalda del roce directo con los bordes de los libros.Y, en caso de no tener más opción que llevar más peso del recomendado, no está de más utilizar maletas de rodachines con los más pequeños, o, si el colegio cuenta con casilleros, poder acceder a uno de ellos para no tener que cargar con los libros todos los días entre la casa y la escuela. Aunque para muchos padres y jóvenes seguir estas recomendaciones pueda parecer difícil, si no imposible, de cumplir, no hacerlo acarrearía importantes problemas de salud.Así lo explica Juan Alberto Castillo, del Laboratorio de Ergonomía de la Escuela de Medicina de la Universidad del Rosario: “Los niños están en proceso de crecimiento, por lo que su estructura muscular y esquelética está en proceso de formación. Entonces, cualquier carga que tengan por fuera de sus límites los afectará”.Los problemas de espalda son más comunes de lo que se cree. Si bien no hay un estudio particular en Colombia, una investigación de la Fundación Kovacs (entidad española sin ánimo de lucro especializada en dolencias de cuello y espalda) concluyó que a los 15 años más del 50 por ciento de los niños y casi el 70 por ciento de las niñas habían sufrido por lo menos una vez en su vida un dolor de espalda.Los efectos de llevar un morral pesado, según Castillo, generalmente no se evidencian inmediatamente sino en el transcurso de la vida: “Las principales repercusiones son lesiones asociadas a la columna vertebral, sobre todo en la espalda baja. Incluso, hay una patología que se ha estudiado en Estados Unidos y se conoce como la parálisis de la mochila, que significa que por el exceso de peso en los músculos, la espalda se afecta y el niño, en el peor de los casos, no puede moverse”.De acuerdo con Gutiérrez, de la U. Manuela Beltrá ...
#  'https://www.eltiempo.com/files/image_640_360/uploads/2020/01/27/5e2ef26288c41.jpeg',
#  '2024-01-26 23:35:17 -05')

# %%
# Paralelizar las solicitudes
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = list(executor.map(fetch_feed_data, ids))



# Crear DataFrame
column_names = ["id", "url", "primerparrafo", "title", "author", "section","content", "thumbnail", "publication_date"]
df = pd.DataFrame(results, columns=column_names)
# Out:
# <ipython-input-121-5352d5945ae0>:9: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   content = " ".join([BeautifulSoup(cont['content'], 'html.parser').get_text() for cont in data['data']['content'] if cont['type'] == 'text' and cont['content'].strip() != ''])
# <ipython-input-121-5352d5945ae0>:12: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   content = " ".join([BeautifulSoup(cont['content'], 'html.parser').get_text() for cont in data['data']['content'] if cont['type'] == 'text' and cont['content'].strip() != ''])

# %%
df
# Out:
#            id                                                url  \
# 0    848961.0  https://www.eltiempo.com/servicios/feeds/artic...
# 1    848959.0  https://www.eltiempo.com/servicios/feeds/artic...
# 2    848956.0  https://www.eltiempo.com/servicios/feeds/artic...
# 3    848753.0  https://www.eltiempo.com/servicios/feeds/artic...
# 4    848878.0  https://www.eltiempo.com/servicios/feeds/artic...
# ..        ...                                                ...
# 984  847944.0  https://www.eltiempo.com/servicios/feeds/artic...
# 985  847966.0  https://www.eltiempo.com/servicios/feeds/artic...
# 986  847965.0  https://www.eltiempo.com/servicios/feeds/artic...
# 987  847839.0  https://www.eltiempo.com/servicios/feeds/artic...
# 988  847943.0  https://www.eltiempo.com/servicios/feeds/artic...
#
#                                          primerparrafo  \
# 0    La doctora nicaragüense Julia Bertha Ríos Terc...
# 1    La embajada de Estados Unidos en México emitió...
# 2    Tras los inicios de los incendios forestales e...
# 3    En los últimos días, múltiples municipios del ...
# 4    Durante los próximos meses, las administracion...
# ..                                                 ...
# 984  Florida se encuentra en medio de un controvert...
# 985  Google, el gigante tecnológico estadounidense,...
# 986  Las personas que sufren de colon irritable deb...
# 987  Un convenio firmado entre la Alcaldía de Barra...
# 988  Después de las interacciones sociales vividas ...
#
#                                                  title  \
# 0    Dos perros pitbull matan a doctora en Nicaragu...
# 1    Estados Unidos recomienda no viajar a Taxco, M...
# 2    EN VIVO | Incendios en Bogotá: en Quebrada la ...
# 3    Bogotá superó esta semana su cifra récord de t...
# 4    ¿Cuáles son los retos de Medellín y Antioquia ...
# ..                                                 ...
# 984  Buscan renovar en Florida una ley que excluye ...
# 985  Google investiga error que bloquea 'smartphone...
# 986  Colon inflamado: esto dicen los expertos sobre...
# 987  Char y Verano firman convenio por $78 mil mill...
# 988  ¿Cómo disminuir el riesgo de problemas respira...
#
#                          author     section  \
# 0                           EFE       Mundo
# 1                           EFE       Mundo
# 2              ÚLTIMAS NOTICIAS      Bogota
# 3       LAURA NATHALIA QUINTERO      Bogota
# 4    SEBASTIÁN CARVAJAL BOLÍVAR    Colombia
# ..                          ...         ...
# 984             DEMIAN MAGALLAN       Mundo
# 985                EUROPA PRESS  Tecnosfera
# 986  LUZ ÁNGELA DOMÍNGUEZ CORAL       Salud
# 987    LEONARDO HERRERA DELGANS    Colombia
# 988          DYLAN ESCOBAR RUIZ       Salud
#
#                                                content  \
# 0    La doctora nicaragüense Julia Bertha Ríos Terc...
# 1    La embajada de Estados Unidos en México emitió...
# 2    Tras los inicios de los incendios forestales e...
# 3    En los últimos días, múltiples municipios del ...
# 4    Durante los próximos meses, las administracion...
# ..                                                 ...
# 984  Florida se encuentra en medio de un controvert...
# 985  Google, el gigante tecnológico estadounidense,...
# 986  Las personas que sufren de colon irritable deb...
# 987  Un convenio firmado entre la Alcaldía de Barra...
# 988  Después de las interacciones sociales vividas ...
#
#                                              thumbnail  \
# 0    https://www.eltiempo.com/files/image_640_360/u...
# 1    https://www.eltiempo.com/files/image_640_360/u...
# 2    https://www.eltiempo.com/files/image_640_360/u...
# 3    https://www.eltiempo.com/files/image_640_360/u...
# 4    https://www.eltiempo.com/files/image_640_360/u...
# ..                                                 ...
# 984  https://www.eltiempo.com/files/image_640_360/u...
# 985  https://www.eltiempo.com/files/article_main_12...
# 986  https://www.eltiempo.com/files/image_640_360/u...
# 987  https://www.eltiempo.com/files/image_640_360/u...
# 988  https://www.eltiempo.com/files/image_640_360/u...
#
#             publication_date
# 0    2024-01-27 01:17:08 -05
# 1    2024-01-27 01:16:00 -05
# 2    2024-01-27 01:14:10 -05
# 3    2024-01-27 00:15:25 -05
# 4    2024-01-27 00:00:00 -05
# ..                       ...
# 984  2024-01-24 14:46:57 -05
# 985  2024-01-24 14:44:20 -05
# 986  2024-01-24 14:44:18 -05
# 987  2024-01-24 14:43:51 -05
# 988  2024-01-24 14:43:19 -05
#
# [989 rows x 9 columns]

# %%
df
# Out:
#            id                                                url  \
# 0    848961.0  https://www.eltiempo.com/servicios/feeds/artic...
# 1    848959.0  https://www.eltiempo.com/servicios/feeds/artic...
# 2    848956.0  https://www.eltiempo.com/servicios/feeds/artic...
# 3    848753.0  https://www.eltiempo.com/servicios/feeds/artic...
# 4    848878.0  https://www.eltiempo.com/servicios/feeds/artic...
# ..        ...                                                ...
# 984  847944.0  https://www.eltiempo.com/servicios/feeds/artic...
# 985  847966.0  https://www.eltiempo.com/servicios/feeds/artic...
# 986  847965.0  https://www.eltiempo.com/servicios/feeds/artic...
# 987  847839.0  https://www.eltiempo.com/servicios/feeds/artic...
# 988  847943.0  https://www.eltiempo.com/servicios/feeds/artic...
#
#                                          primerparrafo  \
# 0    La doctora nicaragüense Julia Bertha Ríos Terc...
# 1    La embajada de Estados Unidos en México emitió...
# 2    Tras los inicios de los incendios forestales e...
# 3    En los últimos días, múltiples municipios del ...
# 4    Durante los próximos meses, las administracion...
# ..                                                 ...
# 984  Florida se encuentra en medio de un controvert...
# 985  Google, el gigante tecnológico estadounidense,...
# 986  Las personas que sufren de colon irritable deb...
# 987  Un convenio firmado entre la Alcaldía de Barra...
# 988  Después de las interacciones sociales vividas ...
#
#                                                  title  \
# 0    Dos perros pitbull matan a doctora en Nicaragu...
# 1    Estados Unidos recomienda no viajar a Taxco, M...
# 2    EN VIVO | Incendios en Bogotá: en Quebrada la ...
# 3    Bogotá superó esta semana su cifra récord de t...
# 4    ¿Cuáles son los retos de Medellín y Antioquia ...
# ..                                                 ...
# 984  Buscan renovar en Florida una ley que excluye ...
# 985  Google investiga error que bloquea 'smartphone...
# 986  Colon inflamado: esto dicen los expertos sobre...
# 987  Char y Verano firman convenio por $78 mil mill...
# 988  ¿Cómo disminuir el riesgo de problemas respira...
#
#                          author     section  \
# 0                           EFE       Mundo
# 1                           EFE       Mundo
# 2              ÚLTIMAS NOTICIAS      Bogota
# 3       LAURA NATHALIA QUINTERO      Bogota
# 4    SEBASTIÁN CARVAJAL BOLÍVAR    Colombia
# ..                          ...         ...
# 984             DEMIAN MAGALLAN       Mundo
# 985                EUROPA PRESS  Tecnosfera
# 986  LUZ ÁNGELA DOMÍNGUEZ CORAL       Salud
# 987    LEONARDO HERRERA DELGANS    Colombia
# 988          DYLAN ESCOBAR RUIZ       Salud
#
#                                              thumbnail  \
# 0               /uploads/2024/01/26/65b48cf939c0e.jpeg
# 1               /uploads/2024/01/26/65b48a05d4a3d.jpeg
# 2               /uploads/2024/01/26/65b4069957771.jpeg
# 3               /uploads/2024/01/25/65b277c23a20b.jpeg
# 4               /uploads/2024/01/26/65b4309d9a745.jpeg
# ..                                                 ...
# 984             /uploads/2023/11/10/654e576f75f2f.jpeg
# 985  https://www.eltiempo.com/files/article_main_12...
# 986             /uploads/2024/01/24/65b16176970a7.jpeg
# 987             /uploads/2024/01/24/65b1677153517.jpeg
# 988             /uploads/2018/09/25/5baab6a7e8e5c.jpeg
#
#             publication_date
# 0    2024-01-27 01:17:08 -05
# 1    2024-01-27 01:16:00 -05
# 2    2024-01-27 01:14:10 -05
# 3    2024-01-27 00:15:25 -05
# 4    2024-01-27 00:00:00 -05
# ..                       ...
# 984  2024-01-24 14:46:57 -05
# 985  2024-01-24 14:44:20 -05
# 986  2024-01-24 14:44:18 -05
# 987  2024-01-24 14:43:51 -05
# 988  2024-01-24 14:43:19 -05
#
# [989 rows x 8 columns]

# %% [markdown]
# Carga este dataframe y explora la herramienta Workbench de Dataproc en GCP para automatizar este proceso cada 3 días.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install faiss-gpu
# Out:
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 8.0 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.1)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: sentencepiece, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.16.1 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 responses-0.18.0 sentencepiece-0.1.99
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
from datasets import Dataset

comments_dataset = Dataset.from_pandas(df)
comments_dataset
# Out:
# Dataset({
#     features: ['id', 'url', 'primerparrafo', 'title', 'author', 'section', 'content', 'thumbnail', 'publication_date'],
#     num_rows: 989
# })

# %%
comments_dataset['content'][0].split()
# Out:
# ['La',
#  'doctora',
#  'nicaragüense',
#  'Julia',
#  'Bertha',
#  'Ríos',
#  'Tercero,',
#  'de',
#  '60',
#  'años,',
#  'falleció',
#  'a',
#  'consecuencia',
#  'de',
#  'las',
#  'heridas',
#  'que',
#  'le',
#  'causaron',
#  'sus',
#  'dos',
#  'perros',
#  'de',
#  'la',
#  'raza',
#  'pitbull,',
#  'hecho',
#  'ocurrido',
#  'en',
#  'su',
#  'finca',
#  'ubicada',
#  'en',
#  'el',
#  'municipio',
#  'de',
#  'El',
#  'Viejo,',
#  'departamento',
#  'de',
#  'Chinandega,',
#  'noroeste',
#  'de',
#  'Nicaragua,',
#  'informó',
#  'este',
#  'viernes',
#  'la',
#  'prensa',
#  'local.(Lo',
#  'invitamos',
#  'a',
#  'seguir',
#  'leyendo:',
#  'Nicaragua',
#  'excarcela',
#  'y',
#  'expulsa',
#  'a',
#  'un',
#  'grupo',
#  'de',
#  'sacerdotes,',
#  'incluido',
#  'al',
#  'obispo',
#  'Álvarez).',
#  'La',
#  'médico',
#  'cirujana,',
#  'defensora',
#  'de',
#  'esos',
#  'animales,',
#  'fue',
#  'atacada',
#  'la',
#  'noche',
#  'del',
#  '25',
#  'de',
#  'enero',
#  'cuando',
#  'intentaba',
#  'alimentar',
#  'a',
#  'sus',
#  'dos',
#  'mascotas,',
#  'que',
#  'la',
#  'desconocieron,',
#  'y',
#  'uno',
#  'de',
#  'los',
#  'perros',
#  'la',
#  'mordió',
#  'mortalmente',
#  'en',
#  'el',
#  'cuello,',
#  'según',
#  'el',
#  'reporte',
#  'de',
#  'la',
#  'emisora',
#  'La',
#  'Nueva',
#  'Radio',
#  'Ya,',
#  'progubernamental.La',
#  'mandíbula',
#  'del',
#  'pitbull',
#  'quedó',
#  'trabada',
#  'en',
#  'el',
#  'cuello',
#  'de',
#  'la',
#  'galena,',
#  'por',
#  'lo',
#  'que',
#  'sus',
#  'familiares',
#  'tuvieron',
#  'que',
#  'matar',
#  'al',
#  'perro.',
#  'La',
#  'mujer',
#  'fue',
#  'trasladada',
#  'a',
#  'un',
#  'centro',
#  'asistencial,',
#  'falleciendo',
#  'en',
#  'el',
#  'trayecto.Este',
#  'es',
#  'el',
#  'tercer',
#  'caso',
#  'que',
#  'se',
#  'da',
#  'en',
#  'Nicaragua',
#  'en',
#  'el',
#  'último',
#  'mes.',
#  '(Puede',
#  'leer:',
#  'Primera',
#  "'baja'",
#  'del',
#  'gabinete',
#  'de',
#  'Milei:',
#  '¿qué',
#  'pasará',
#  'con',
#  'el',
#  'Ministerio',
#  'de',
#  'Infraestructura?).El',
#  'pasado',
#  '28',
#  'de',
#  'diciembre,',
#  'la',
#  'nicaragüense',
#  'Ana',
#  'Rosa',
#  'Aguilera',
#  'Blandón,',
#  'de',
#  '83',
#  'años,',
#  'perdió',
#  'la',
#  'vida',
#  'tras',
#  'ser',
#  'atacada',
#  'en',
#  'su',
#  'casa',
#  'y',
#  'por',
#  'su',
#  'propio',
#  'perro',
#  'de',
#  'raza',
#  'pitbull,',
#  'en',
#  'la',
#  'ciudad',
#  'colonial',
#  'de',
#  'Granada,',
#  'suroeste',
#  'de',
#  'Managua.Y',
#  'el',
#  'pasado',
#  '1',
#  'de',
#  'enero,',
#  'el',
#  'nicaragüense',
#  'Augusto',
#  'José',
#  'García,',
#  'de',
#  '21',
#  'años,',
#  'murió',
#  'a',
#  'consecuencia',
#  'de',
#  'las',
#  'heridas',
#  'que',
#  'le',
#  'causaron',
#  'sus',
#  'cinco',
#  'perros,',
#  'de',
#  'la',
#  'raza',
#  'rottweiler,',
#  'mientras',
#  'estaba',
#  'en',
#  'su',
#  'casa,',
#  'en',
#  'un',
#  'barrio',
#  'de',
#  'Managua.Por',
#  'esos',
#  'casos,',
#  'que',
#  'causaron',
#  'debate',
#  'en',
#  'Nicaragua',
#  'sobre',
#  'si',
#  'se',
#  'deben',
#  'o',
#  'no',
#  'matar',
#  'a',
#  'los',
#  'perros',
#  'si',
#  'atacan',
#  'a',
#  'una',
#  'persona,',
#  'la',
#  'hoy',
#  'occisa',
#  'doctora',
#  'Ríos',
#  'escribió',
#  'en',
#  'la',
#  'red',
#  'social',
#  'de',
#  'Facebook',
#  'que',
#  '"no',
#  'es',
#  'justo"',
#  'sacrificarlos',
#  'y',
#  'que',
#  'tienen',
#  'derecho',
#  'a',
#  'vivir.',
#  'EFE']

# %%
comments_dataset = comments_dataset.map(
    lambda x: {"comment_length": len(x["content"].split())} if x["content"] is not None and "content" in x else {"comment_length": 0}
)
# Out:
# Map:   0%|          | 0/989 [00:00<?, ? examples/s]

# %%
comments_dataset = comments_dataset.filter(lambda x: x["comment_length"] > 15)
comments_dataset
# Out:
# Filter:   0%|          | 0/989 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'url', 'primerparrafo', 'title', 'author', 'section', 'content', 'thumbnail', 'publication_date', 'comment_length'],
#     num_rows: 969
# })

# %%
def concatenate_text(examples):
    return {
        "text": examples["title"]
        + " \n "
        + examples["content"]

    }


comments_dataset = comments_dataset.map(concatenate_text)
# Out:
# Map:   0%|          | 0/969 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer, TFAutoModel

model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = TFAutoModel.from_pretrained(model_ckpt, from_pt=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFMPNetModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMPNetModel for predictions without further training.

# %%
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]

# %%
def get_embeddings(text_list):
    encoded_input = tokenizer(
        text_list, padding=True, truncation=True, return_tensors="tf"
    )
    encoded_input = {k: v for k, v in encoded_input.items()}
    model_output = model(**encoded_input)
    return cls_pooling(model_output)

# %%
embedding = get_embeddings(comments_dataset["text"][0])
embedding.shape
# Out:
# TensorShape([1, 768])

# %%
comments_dataset.select(list(range(3)))
# Out:
# Dataset({
#     features: ['id', 'url', 'primerparrafo', 'title', 'author', 'section', 'content', 'thumbnail', 'publication_date', 'comment_length', 'text'],
#     num_rows: 3
# })

# %%
embeddings_dataset = comments_dataset.map(
    lambda x: {"embeddings": get_embeddings(x["text"]).numpy()[0]}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Map:   0%|          | 0/969 [00:00<?, ? examples/s]

# %%
embeddings_dataset.add_faiss_index(column="embeddings")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['id', 'url', 'primerparrafo', 'title', 'author', 'section', 'content', 'thumbnail', 'publication_date', 'comment_length', 'text', 'embeddings'],
#     num_rows: 969
# })

# %%
question = "Televisión Colombiana"
question_embedding = get_embeddings([question]).numpy()
question_embedding.shape
# Out:
# (1, 768)

# %%
scores, samples = embeddings_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=10
)

# %%
import pandas as pd

samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores
samples_df.sort_values("scores", ascending=False, inplace=True)

# %%
row
# Out:
# id                                                           847934.0
# url                 https://www.eltiempo.com/servicios/feeds/artic...
# primerparrafo       Hace poco, el actor Julián Román, de 46 años, ...
# title               Julián Román dio a conocer cuánto gana un acto...
# author                                                KAREN CASTAÑEDA
# section                                                       Cultura
# content             Hace poco, el actor Julián Román, de 46 años, ...
# thumbnail           https://www.eltiempo.com/files/image_640_360/u...
# publication_date                              2024-01-25 00:00:00 -05
# comment_length                                                    565
# text                Julián Román dio a conocer cuánto gana un acto...
# embeddings          [-0.08559063822031021, 0.7803407907485962, -0....
# scores                                                      39.858849
# Name: 0, dtype: object

# %%
for _, row in samples_df.iterrows():
    print(f"COMMENT: {row.primerparrafo}")
    print(f"SCORE: {row.scores}")
    print(f"TITLE: {row.title}")
    print(f"URL: {row.url}")
    print("=" * 50)
    print()
# Out:
# COMMENT: La Selección Colombia Sub-23 de fútbol se enfrenta este viernes contra su similar de Brasil por la tercera fecha del Torneo Preolímpico de Suramérica con sede en Venezuela.Puede ser de su interés: Mindeporte: se filtra posible relevo en gabinete de Petro tras pérdida de Panamericanos
# SCORE: 35.383140563964844
# TITLE: La Selección Colombia Sub-23 pierde contra Brasil: video de los goles del Preolímpico
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848901
# ==================================================
#
# COMMENT: Como ocurrió en Estados Unidos, HBO Max se transformará en Latinoamérica. La plataforma de streaming, con variedad de series y películas, tendrá ajustes tras la fusión de las compañías Warner Bros. y Discovery.
# SCORE: 34.94790267944336
# TITLE: HBO Max cambia en Colombia: anuncian fecha, precios y qué pasará con suscriptores
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848216
# ==================================================
#
# COMMENT: En la noche de este viernes, 26 de enero, se conoció del fallecimiento de Julio Sánchez Vanegas, a los 93 años, uno de los hombres que hizo parte del desarrollo de los medios de comunicación en Colombia. (En contexto: Murió Julio Sánchez Vanegas, leyenda de los medios de comunicación en Colombia).
# SCORE: 34.86880111694336
# TITLE: Los hitos de Julio Sánchez Vanegas en los medios de comunicación en Colombia
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848913
# ==================================================
#
# COMMENT: La Selección Colombia sub-23 necesita levantarse este viernes en el Preolímpico y buscar la épica para derrotar a Brasil en su segundo juego del grupo A (6 p. m. TV de Caracol, RCN y DSports), luego de haber perdido 3-0 contra Ecuador.
# SCORE: 34.155025482177734
# TITLE: Colombia, ante el peor escenario: ganarle sí o sí a Brasil en el Preolímpico
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848548
# ==================================================
#
# COMMENT: La ilusión de volver a los Juegos Olímpicos en fútbol masculino duró 180 minutos. Colombia quedó eliminada este viernes, tras perder 2-0 contra Brasil en Caracas, y ya no tiene ninguna opción aritmética de clasificar a la fase final del Preolímpico de Venezuela.
# SCORE: 34.09333419799805
# TITLE: Selección Colombia: nuevo fracaso en el Preolímpico, derrotada y eliminada
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848924
# ==================================================
#
# COMMENT: Un mensaje de su tía Gloria llegó a conmover hasta las lágrimas a la actriz barranquillera Sofía Vergara, quien ha confesado que justamente esa familiar la inspiró para caracterizar su personaje de la serie 'Griselda'.
# SCORE: 33.65799331665039
# TITLE: Sofía Vergara se inspiró en su tía Gloria, para su personaje de Griselda
# URL: https://www.eltiempo.com/servicios/feeds/articulo/847974
# ==================================================
#
# COMMENT: RTVC, el Sistema de Medios Públicos, en cabeza de su gerente Nórida Rodríguez, informó que los equipos de Bomberos lograron apaciguar las llamas que amenazaban con destruir la Estación de Transmisión que RTVC tiene ubicada allí y de la que hacen parte un salón de equipos y la vivienda del cuidador, quien ya fue evacuado.
# SCORE: 33.027801513671875
# TITLE: Llamas en cerro El Cable amenazan con destruir la Estación de Transmisión de RTVC
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848238
# ==================================================
#
# COMMENT: Julio Sánchez Vanegas, uno de los hombres claves del desarrollo y el crecimiento de los medios de comunicación en Colombia, falleció este viernes, 26 de enero.
# SCORE: 29.010412216186523
# TITLE: Murió Julio Sánchez Vanegas, leyenda de los medios de comunicación en Colombia
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848907
# ==================================================
#
# COMMENT: El fallecimiento en la tarde de este viernes, 26 de enero, de uno de los pioneros de la televisión colombiana, Julio Sánchez Vanegas, genera mensajes cargados de nostalgia entre colombianos que lo recuerdan con cariño.(Puede leer: Murió Julio Sánchez Vanegas, leyenda de los medios de comunicación en Colombia)
# SCORE: 26.59241485595703
# TITLE: Así despiden a Julio Sánchez Vanegas, pionero de la televisión que murió este viernes
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848921
# ==================================================
#
# COMMENT: La memoria ya no era tan fiel y su salud se había ido deteriorando, pero Julio E. Sánchez Vanegas seguía siendo ese hombre imponente que presentó, el 13 de junio de 1954, la televisión que llegaba a Colombia, como maestro de ceremonias del general Gustavo Rojas Pinilla, en ese momento presidente del país.
# SCORE: 26.530881881713867
# TITLE: Se fue Julio E. Sánchez Vanegas, uno de los más grandes de la TV nacional
# URL: https://www.eltiempo.com/servicios/feeds/articulo/848938
# ==================================================

# %%
# prompt: es posible darle un contexto que no tenga en cuenta el embedig que esta arriba

print("This code is not related to the provided context.")
